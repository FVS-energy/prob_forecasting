# %% [markdown]
# # Import packages

# %%
import numpy as np
import pandas as pd
import math
from matplotlib import pyplot as plt
from numpy import array
import tensorflow as tf
import pickle
import keras
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import concatenate
from keras.layers.recurrent import LSTM,GRU
from sklearn.model_selection import TimeSeriesSplit
import time
import itertools
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Helper Funtions

# %%
list_features_withWeather = ['time of day_1.0', 'time of day_2.0', 'time of day_3.0', 'time of day_4.0', 'time of day_5.0', 'time of day_6.0', 
              'time of day_7.0', 'time of day_8.0', 'time of day_9.0', 'time of day_10.0', 'time of day_11.0', 'time of day_12.0', 
              'time of day_13.0', 'time of day_14.0', 'time of day_15.0', 'time of day_16.0', 'time of day_17.0', 'time of day_18.0', 
              'time of day_19.0', 'time of day_20.0', 'time of day_21.0', 'time of day_22.0', 'time of day_23.0', 'time of day_24.0',
              'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 'weekday_7',
              'temp(C)',  'wind_speed(Km/h)', 'rel_humi']

list_features_noWeather = ['time of day_1.0', 'time of day_2.0', 'time of day_3.0', 'time of day_4.0', 'time of day_5.0', 'time of day_6.0', 
              'time of day_7.0', 'time of day_8.0', 'time of day_9.0', 'time of day_10.0', 'time of day_11.0', 'time of day_12.0', 
              'time of day_13.0', 'time of day_14.0', 'time of day_15.0', 'time of day_16.0', 'time of day_17.0', 'time of day_18.0', 
              'time of day_19.0', 'time of day_20.0', 'time of day_21.0', 'time of day_22.0', 'time of day_23.0', 'time of day_24.0',
              'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 'weekday_7']  


def normalize(df, column_list):
    result = df.copy()
    # encoding 'time of the day' and 'weekday' to dummies
    result = pd.get_dummies(result, columns = ['time of day', 'weekday'])
    for feature_name in column_list:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result


def split_sequence(sequence, n_steps_in, n_steps_out):
    """
    split time series to X and y with predefined n_steps_in, n_steps_out
    for example n_steps_in = 336, n_steps_out = 1 use 336 time points to generate 1-hour-ahead prediction
    ----------
    Parameters:
    sequence : time series
    n_steps_in: length of historical net load input in hours
    n_steps_out: length of net load prediction horizon in hours
    ----------
    return: Input sequence X as array, y sequence as array 
    """
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of the sequence
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are out of range
        if out_end_ix+1 > len(sequence):
            break
        # define input and output sequence
        seq_x, seq_y = sequence[i:end_ix], sequence[out_end_ix:out_end_ix+1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)


def pinball_loss(q, y, f):
    """
    define loss function
    ----------
    Parameters:
    q: quantile
    y: real observation
    f: forecast
    ----------
    return: loss function 
    """
    e = (y-f)
    return keras.backend.mean(keras.backend.maximum(q*e, (q-1)*e), axis=-1)


def run_model(input_data, n_train, n_steps_in, n_steps_out, weather_included, method, learning_rate, n_unit, n_Dense_unit, n_batch_size, 
              n_epochs, n_test):
    """
    This function first builds the model, trains the model and then tests the model
    ----------
    Parameters:
    input_data: input_data
    n_train: length of training set
    n_steps_in: length of historical net load input in hours
    n_steps_out: length of net load prediction horizon in hours
    weather_included: Boolean indicating whether weather data are to be taken into account 
    method: desired prediction method (GRU, LSTM, Regression)
    n_test: length of test set

    hyperparameters:
    learning_rate: learning rate
    n_unit: amount of neurons in recurrent hidden layers
    n_Dense_unit: amount of neurons in dense hidden layers
    n_batch_size: batch size
    n_epochs: epochs
    
    ----------
    return: 
    yhat: forecast
    train_loss: loss on train set
    test_loss: loss on test set
    train_time: time needed for model training
    """
    
    
    if weather_included == 1:
        X2_feature_list = list_features_withWeather
    else:
        X2_feature_list = list_features_noWeather
    
    # Set X1_train, X2_train, and y_train
    X1_seq = input_data['net_consumption'].values.flatten().tolist()[0:n_train]
    X1_train, y_train =  split_sequence(X1_seq, n_steps_in, n_steps_out)
    X1_train = X1_train.reshape((X1_train.shape[0], X1_train.shape[1], 1))
    X2_train = input_data[X2_feature_list][(n_steps_in + n_steps_out):n_train].values.flatten()
    X2_train = X2_train.reshape((X1_train.shape[0], len(X2_feature_list)))
    
    # build model according to figure 3 in the paper
    if method == "LSTM":
        input1 = Input(shape=(n_steps_in, 1))
        input2 = Input(shape=(len(X2_feature_list),))
        recurrent_hidden1 = LSTM(n_unit, activation='sigmoid', return_sequences=True, bias_regularizer='l2')(input1)
        recurrent_hidden2 = LSTM(n_unit, activation='relu', bias_regularizer='l2')(recurrent_hidden1)
        recurrent_output = Dense(1, activation='sigmoid')(recurrent_hidden2)
        merge = keras.layers.concatenate([recurrent_output, input2])
        hidden1 = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(merge)
        hidden_last = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(hidden1)
    elif method == "GRU":
        input1 = Input(shape=(n_steps_in, 1))
        input2 = Input(shape=(len(X2_feature_list),))
        recurrent_hidden1 = GRU(n_unit, activation='sigmoid', return_sequences=True, bias_regularizer='l2')(input1)
        recurrent_hidden2 = GRU(n_unit, activation='relu', bias_regularizer='l2')(recurrent_hidden1)
        recurrent_output = Dense(1, activation='sigmoid')(recurrent_hidden2)
        merge = keras.layers.concatenate([recurrent_output, input2])
        hidden1 = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(merge)
        hidden_last = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(hidden1)
    elif method == "Regression":
        input1 = Input(shape=(n_steps_in,)) # this differs from GRU and LSTM model
        input2 = Input(shape=(len(X2_feature_list),))
        merge = keras.layers.concatenate([input1, input2])
        hidden1 = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(merge)
        hidden2 = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(hidden1)
        hidden3 = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(hidden2)
        hidden_last = Dense(n_Dense_unit, activation='relu', bias_regularizer='l2')(hidden3)        

    output_10 = Dense(1, activation='sigmoid', name='output_10')(hidden_last)
    output_25 = Dense(1, activation='sigmoid', name='output_25')(hidden_last)
    output_50 = Dense(1, activation='sigmoid', name='output_50')(hidden_last)
    output_75 = Dense(1, activation='sigmoid', name='output_75')(hidden_last)
    output_90 = Dense(1, activation='sigmoid', name='output_90')(hidden_last)
    model = Model(inputs=[input1, input2], outputs=[output_10, output_25, output_50, output_75, output_90])
    
    optimizer = keras.optimizers.Adam(learning_rate = learning_rate, beta_1=0.9,
      beta_2=0.999, epsilon=1e-07,)

    model.compile(loss={'output_10': lambda y,f: pinball_loss(0.10,y,f), 
                        'output_25': lambda y,f: pinball_loss(0.25,y,f),
                        'output_50': lambda y,f: pinball_loss(0.50,y,f),
                        'output_75': lambda y,f: pinball_loss(0.75,y,f),
                        'output_90': lambda y,f: pinball_loss(0.90,y,f)},
                  optimizer=optimizer)
    
    # fit model
    start = time.time()
    history = model.fit([X1_train, X2_train], [y_train, y_train, y_train, y_train, y_train], epochs=n_epochs,  batch_size=n_batch_size, shuffle=False)


    print("fit complete!")
    end = time.time()
    train_time = end - start
    print("train_time is: " + str(train_time) + " seconds") 
    
    train_loss = model.evaluate([X1_train, X2_train], [y_train, y_train, y_train, y_train, y_train])
    print("train_loss is: " + str(train_loss))
    
    # test model
    n_total = input_data.shape[0]
    X1_test_seq = input_data['net_consumption'].values.flatten().tolist()[n_train - n_steps_in - n_steps_out:n_test]
    X1_test, y_test =  split_sequence(X1_test_seq, n_steps_in, n_steps_out)
    X1_test = X1_test.reshape((X1_test.shape[0], X1_test.shape[1], 1))
    X2_test = input_data[X2_feature_list][n_train:n_test].values.flatten()
    X2_test = X2_test.reshape((X1_test.shape[0], len(X2_feature_list)))
    yhat = model.predict([X1_test, X2_test])
    test_loss = model.evaluate([X1_test, X2_test], [y_test, y_test, y_test, y_test, y_test])
    print("test_loss is: " + str(test_loss))
    
    
    return yhat, train_loss, test_loss, train_time

def summarize_result(yhat, id, method, weather_included, n_test, learning_rate, n_Dense_unit, n_unit):
    """
    summarize forecast and corresponding loss 
    ----------
    Parameters:
    yhat: forecast
    id: Household id 
    method: desired forecast method (GRU, LSTM, Regression)
    weather_included: Boolean indicating whether weather data are to be taken into account
    n_test: length of test set

    learning_rate: learning rate
    n_Dense_unit: amount of neurons in dense hidden layers
    n_unit: amount of neurons in recurrent hidden layers
    ----------
    return: 
    result_yhat: forecast
    result_loss: forecast loss
    """
  
    columns_list = ['id', 'method', 'weather_included', 'quantile', 'train_loss', 'test_loss', 'learning_rate', 'n_Dense_unit', 'n_unit']+ list(range(1, n_test-n_train+1))
    result_yhat = pd.DataFrame(columns=columns_list)
    q = ['10%', '25%', '50%', '75%', '90%']
    for i in range(0,5):
        result_list = [id, method, weather_included, q[i], yhat[1][i+1], yhat[2][i+1], learning_rate, n_Dense_unit, n_unit] + yhat[0][i].flatten().tolist()
        result = pd.DataFrame([result_list],columns=columns_list)
        result_yhat= result_yhat.append(result)
        
    columns_list = ['id', 'method', 'weather_included', 'time', 'train_loss', 'test_loss', 'learning_rate', 'n_Dense_unit', 'n_unit']
    result_loss = pd.DataFrame(columns=columns_list)
    result_list = [id, method, weather_included, yhat[3], yhat[1][0], yhat[2][0], learning_rate, n_Dense_unit, n_unit]
    result = pd.DataFrame([result_list],columns=columns_list)
    result_loss= result_loss.append(result)
    return result_yhat, result_loss


def forecast(input_data, id, n_steps_out, n_total, n_train, n_steps_in, n_test, hyper_params, path):
    """
    Performes forecasting, saves results and returns a list of forecast results and list of corresponding losses
    ----------
    Parameters:
    input_data: input_data
    id: Household ids
    n_steps_out: length of net load prediction horizon in hours
    n_total: length of total data set 
    n_train: length of training set
    n_steps_in: length of historical net load input in hours
    n_test: length of test set
    hyper_params: set of hyperparameters
    path: output path
    ----------
    return: 
    yhat_list: list of forecast results
    loss_list: list of corresponding losses 
    """
    input_data = input_data.loc[input_data['id'] == id].head(n_total)
    yhat_list = pd.DataFrame()
    loss_list = pd.DataFrame()
    for method, weather_included, learning_rate, n_Dense_unit, n_unit in hyper_params:
        print ("learning_rate, n_unit, n_Dense_unit: ", learning_rate, n_unit, n_Dense_unit)
        yhat = run_model(input_data, n_train, n_steps_in, n_steps_out, weather_included, method, learning_rate, n_unit, n_Dense_unit, n_batch_size, n_epochs, n_test)
        yhat, loss = summarize_result(yhat, id, method, weather_included, n_test, learning_rate, n_Dense_unit, n_unit)
        yhat_list = yhat_list.append(yhat)
        loss_list = loss_list.append(loss)
        print('\n')
    yhat_list.to_pickle(path+'/yhat_net_'+str(id)+'_'+method+'_'+str(weather_included))
    loss_list.to_pickle(path+'/loss_net_'+str(id)+'_'+method+'_'+str(weather_included))
    return yhat_list, loss_list

# %%
# Read in data 
input_data = pd.read_pickle('ProbabilisticLoadForecasting/data/input/preprocessed_input_data')
id_list = input_data['id'].unique()
id_list = id_list.tolist() # a list with the ids of all (40) houses
id_list = id_list
input_data = normalize(input_data, ['net_consumption', 'temp(C)', 'wind_speed(Km/h)', 'rel_humi'])

# %% [markdown]
# Due to the time series character and the limited time range of the data (one year), a **two-fold rolling window approach** is conducted to cross-validate the models. First, we train, validate and test our models only on the first 80% of data, i.e. with a train-validation-test split of 40-20-20. Second, we expand the training window, resulting in a 60-20-20 split. For the final evaluation, we average the test losses from step one and two.

# %%
#this cell calls the forecasting function
#select the desired method, parameters and data set split 

## Data set split
#number of total observations
n_total = len(input_data.index.unique()) 
# number of observations used for training
n_train = int(round(n_total * 0.4, 0)) # for cross-validation with expanding window approach, you can repeat the calculations with other factors e.g.: 0.5, 0.6 
# number of observations used for testing
n_test = int(n_train + round(n_total * 0.2, 0))

## Sliding window
# length of historical net load input in hours
n_steps_in = 336
# length of net load prediction horizon in hours
n_steps_out = 1


##Modelparameters
method = 'GRU' # GRU, LSTM, Regression
weather_included = 1 # 1: withWeather, 0: withoutWeather


##hyperparameters that are not tuned 
n_epochs = 15
n_batch_size = 2048 

##Hyperparameters to tune

hyper_params = [(method, weather_included, 0.001, 10, 4), (method, weather_included, 0.001, 10, 8), (method, weather_included, 0.001, 10, 12),
                (method, weather_included, 0.001, 30, 4), (method, weather_included, 0.001, 30, 8), (method, weather_included, 0.001, 30, 12),
                (method, weather_included, 0.001, 50, 4), (method, weather_included, 0.001, 50, 8), (method, weather_included, 0.001, 50, 12),
                (method, weather_included, 0.01, 10, 4), (method, weather_included, 0.01, 10, 8), (method, weather_included, 0.01, 10, 12),
                (method, weather_included, 0.01, 30, 4), (method, weather_included, 0.01, 30, 8), (method, weather_included, 0.01, 30, 12),
                (method, weather_included, 0.01, 50, 4), (method, weather_included, 0.01, 50, 8), (method, weather_included, 0.01, 50, 12),
                (method, weather_included, 0.1, 10, 4), (method, weather_included, 0.1, 10, 8), (method, weather_included, 0.1, 10, 12),
                (method, weather_included, 0.1, 30, 4), (method, weather_included, 0.1, 30, 8), (method, weather_included, 0.1, 30, 12),
                (method, weather_included, 0.1, 50, 4), (method, weather_included, 0.1, 50, 8), 
                (method, weather_included, 0.1, 50, 12)
                ]

path = '' #Set output path  

for i in id_list:
    print('id: ', i)
    locals()['yhat_net_'+str(i)], locals()['yloss_net_'+str(i)] =  forecast(input_data, i , n_steps_out, n_total, n_train, n_steps_in, n_test, hyper_params, path)
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# fit complete!
# train_time is: 23.626830339431763 seconds
# 100/100 [==============================] - 5s 41ms/step - loss: 0.3820 - output_10_loss: 0.1334 - output_25_loss: 0.0832 - output_50_loss: 0.0810 - output_75_loss: 0.0570 - output_90_loss: 0.0268
# train_loss is: [0.3820449113845825, 0.13341447710990906, 0.083172507584095, 0.08102605491876602, 0.057009004056453705, 0.02680768445134163]
# 55/55 [==============================] - 2s 38ms/step - loss: 0.2864 - output_10_loss: 0.0992 - output_25_loss: 0.0523 - output_50_loss: 0.0612 - output_75_loss: 0.0492 - output_90_loss: 0.0238
# test_loss is: [0.2864362895488739, 0.09924765676259995, 0.05233195796608925, 0.061223652213811874, 0.04923900589346886, 0.02377885952591896]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.001 12 50
# Epoch 1/15
# 2/2 [==============================] - 6s 689ms/step - loss: 0.7136 - output_10_loss: 0.2529 - output_25_loss: 0.2245 - output_50_loss: 0.1435 - output_75_loss: 0.0669 - output_90_loss: 0.0258
# Epoch 2/15
# 2/2 [==============================] - 2s 666ms/step - loss: 0.6845 - output_10_loss: 0.2380 - output_25_loss: 0.2143 - output_50_loss: 0.1408 - output_75_loss: 0.0662 - output_90_loss: 0.0252
# Epoch 3/15
# 2/2 [==============================] - 2s 653ms/step - loss: 0.6555 - output_10_loss: 0.2231 - output_25_loss: 0.2044 - output_50_loss: 0.1380 - output_75_loss: 0.0654 - output_90_loss: 0.0246
# Epoch 4/15
# 2/2 [==============================] - 2s 686ms/step - loss: 0.6261 - output_10_loss: 0.2082 - output_25_loss: 0.1945 - output_50_loss: 0.1351 - output_75_loss: 0.0644 - output_90_loss: 0.0239
# Epoch 5/15
# 2/2 [==============================] - 2s 651ms/step - loss: 0.5963 - output_10_loss: 0.1929 - output_25_loss: 0.1846 - output_50_loss: 0.1322 - output_75_loss: 0.0633 - output_90_loss: 0.0231
# Epoch 6/15
# 2/2 [==============================] - 2s 646ms/step - loss: 0.5657 - output_10_loss: 0.1773 - output_25_loss: 0.1747 - output_50_loss: 0.1292 - output_75_loss: 0.0620 - output_90_loss: 0.0224
# Epoch 7/15
# 2/2 [==============================] - 2s 653ms/step - loss: 0.5340 - output_10_loss: 0.1611 - output_25_loss: 0.1645 - output_50_loss: 0.1261 - output_75_loss: 0.0606 - output_90_loss: 0.0215
# Epoch 8/15
# 2/2 [==============================] - 2s 666ms/step - loss: 0.5008 - output_10_loss: 0.1443 - output_25_loss: 0.1540 - output_50_loss: 0.1229 - output_75_loss: 0.0588 - output_90_loss: 0.0205
# Epoch 9/15
# 2/2 [==============================] - 2s 662ms/step - loss: 0.4661 - output_10_loss: 0.1269 - output_25_loss: 0.1430 - output_50_loss: 0.1196 - output_75_loss: 0.0568 - output_90_loss: 0.0195
# Epoch 10/15
# 2/2 [==============================] - 2s 676ms/step - loss: 0.4293 - output_10_loss: 0.1087 - output_25_loss: 0.1312 - output_50_loss: 0.1160 - output_75_loss: 0.0545 - output_90_loss: 0.0184
# Epoch 11/15
# 2/2 [==============================] - 2s 659ms/step - loss: 0.3902 - output_10_loss: 0.0898 - output_25_loss: 0.1186 - output_50_loss: 0.1122 - output_75_loss: 0.0520 - output_90_loss: 0.0172
# Epoch 12/15
# 2/2 [==============================] - 2s 665ms/step - loss: 0.3488 - output_10_loss: 0.0701 - output_25_loss: 0.1051 - output_50_loss: 0.1081 - output_75_loss: 0.0491 - output_90_loss: 0.0159
# Epoch 13/15
# 2/2 [==============================] - 2s 680ms/step - loss: 0.3052 - output_10_loss: 0.0500 - output_25_loss: 0.0906 - output_50_loss: 0.1036 - output_75_loss: 0.0458 - output_90_loss: 0.0145
# Epoch 14/15
# 2/2 [==============================] - 2s 662ms/step - loss: 0.2606 - output_10_loss: 0.0310 - output_25_loss: 0.0750 - output_50_loss: 0.0986 - output_75_loss: 0.0422 - output_90_loss: 0.0130
# Epoch 15/15
# 2/2 [==============================] - 2s 681ms/step - loss: 0.2184 - output_10_loss: 0.0167 - output_25_loss: 0.0584 - output_50_loss: 0.0929 - output_75_loss: 0.0381 - output_90_loss: 0.0114
# fit complete!
# train_time is: 32.13194751739502 seconds
# 100/100 [==============================] - 4s 39ms/step - loss: 0.1842 - output_10_loss: 0.0091 - output_25_loss: 0.0428 - output_50_loss: 0.0872 - output_75_loss: 0.0342 - output_90_loss: 0.0098
# train_loss is: [0.1841561496257782, 0.009144444018602371, 0.04281297326087952, 0.08723969757556915, 0.03420025110244751, 0.009825353510677814]
# 55/55 [==============================] - 2s 37ms/step - loss: 0.1259 - output_10_loss: 0.0062 - output_25_loss: 0.0177 - output_50_loss: 0.0706 - output_75_loss: 0.0237 - output_90_loss: 0.0067
# test_loss is: [0.1259012222290039, 0.006231621373444796, 0.017670821398496628, 0.07063692808151245, 0.02373461052775383, 0.006693817209452391]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 4 10
# Epoch 1/15
# 2/2 [==============================] - 5s 425ms/step - loss: 0.7284 - output_10_loss: 0.3408 - output_25_loss: 0.1764 - output_50_loss: 0.1052 - output_75_loss: 0.0823 - output_90_loss: 0.0237
# Epoch 2/15
# 2/2 [==============================] - 1s 408ms/step - loss: 0.6151 - output_10_loss: 0.3021 - output_25_loss: 0.1423 - output_50_loss: 0.0862 - output_75_loss: 0.0640 - output_90_loss: 0.0205
# Epoch 3/15
# 2/2 [==============================] - 1s 399ms/step - loss: 0.5070 - output_10_loss: 0.2729 - output_25_loss: 0.1055 - output_50_loss: 0.0635 - output_75_loss: 0.0490 - output_90_loss: 0.0158
# Epoch 4/15
# 2/2 [==============================] - 1s 399ms/step - loss: 0.3986 - output_10_loss: 0.2440 - output_25_loss: 0.0674 - output_50_loss: 0.0402 - output_75_loss: 0.0351 - output_90_loss: 0.0113
# Epoch 5/15
# 2/2 [==============================] - 1s 400ms/step - loss: 0.3066 - output_10_loss: 0.2092 - output_25_loss: 0.0359 - output_50_loss: 0.0252 - output_75_loss: 0.0220 - output_90_loss: 0.0132
# Epoch 6/15
# 2/2 [==============================] - 1s 405ms/step - loss: 0.2517 - output_10_loss: 0.1632 - output_25_loss: 0.0213 - output_50_loss: 0.0242 - output_75_loss: 0.0166 - output_90_loss: 0.0249
# Epoch 7/15
# 2/2 [==============================] - 1s 413ms/step - loss: 0.2147 - output_10_loss: 0.1098 - output_25_loss: 0.0179 - output_50_loss: 0.0275 - output_75_loss: 0.0187 - output_90_loss: 0.0388
# Epoch 8/15
# 2/2 [==============================] - 1s 399ms/step - loss: 0.1743 - output_10_loss: 0.0613 - output_25_loss: 0.0173 - output_50_loss: 0.0278 - output_75_loss: 0.0182 - output_90_loss: 0.0474
# Epoch 9/15
# 2/2 [==============================] - 1s 396ms/step - loss: 0.1333 - output_10_loss: 0.0284 - output_25_loss: 0.0159 - output_50_loss: 0.0238 - output_75_loss: 0.0138 - output_90_loss: 0.0488
# Epoch 10/15
# 2/2 [==============================] - 1s 396ms/step - loss: 0.0999 - output_10_loss: 0.0136 - output_25_loss: 0.0134 - output_50_loss: 0.0169 - output_75_loss: 0.0117 - output_90_loss: 0.0415
# Epoch 11/15
# 2/2 [==============================] - 1s 433ms/step - loss: 0.0756 - output_10_loss: 0.0084 - output_25_loss: 0.0112 - output_50_loss: 0.0120 - output_75_loss: 0.0138 - output_90_loss: 0.0272
# Epoch 12/15
# 2/2 [==============================] - 1s 397ms/step - loss: 0.0632 - output_10_loss: 0.0063 - output_25_loss: 0.0103 - output_50_loss: 0.0147 - output_75_loss: 0.0154 - output_90_loss: 0.0134
# Epoch 13/15
# 2/2 [==============================] - 1s 407ms/step - loss: 0.0580 - output_10_loss: 0.0050 - output_25_loss: 0.0098 - output_50_loss: 0.0186 - output_75_loss: 0.0146 - output_90_loss: 0.0068
# Epoch 14/15
# 2/2 [==============================] - 1s 425ms/step - loss: 0.0514 - output_10_loss: 0.0044 - output_25_loss: 0.0086 - output_50_loss: 0.0169 - output_75_loss: 0.0117 - output_90_loss: 0.0067
# Epoch 15/15
# 2/2 [==============================] - 1s 412ms/step - loss: 0.0434 - output_10_loss: 0.0045 - output_25_loss: 0.0077 - output_50_loss: 0.0111 - output_75_loss: 0.0086 - output_90_loss: 0.0080
# fit complete!
# train_time is: 19.16094422340393 seconds
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0404 - output_10_loss: 0.0053 - output_25_loss: 0.0083 - output_50_loss: 0.0067 - output_75_loss: 0.0079 - output_90_loss: 0.0088
# train_loss is: [0.040448013693094254, 0.005250713787972927, 0.008261363953351974, 0.00674988329410553, 0.007903248071670532, 0.00883335992693901]
# 55/55 [==============================] - 2s 39ms/step - loss: 0.1194 - output_10_loss: 0.0107 - output_25_loss: 0.0239 - output_50_loss: 0.0294 - output_75_loss: 0.0443 - output_90_loss: 0.0076
# test_loss is: [0.11936549097299576, 0.010705667547881603, 0.02388312853872776, 0.02944926545023918, 0.04432611167430878, 0.007551885209977627]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 8 10
# Epoch 1/15
# 2/2 [==============================] - 5s 539ms/step - loss: 0.6901 - output_10_loss: 0.2453 - output_25_loss: 0.2129 - output_50_loss: 0.1430 - output_75_loss: 0.0660 - output_90_loss: 0.0228
# Epoch 2/15
# 2/2 [==============================] - 1s 538ms/step - loss: 0.6349 - output_10_loss: 0.2208 - output_25_loss: 0.1973 - output_50_loss: 0.1315 - output_75_loss: 0.0628 - output_90_loss: 0.0223
# Epoch 3/15
# 2/2 [==============================] - 1s 546ms/step - loss: 0.5789 - output_10_loss: 0.1945 - output_25_loss: 0.1832 - output_50_loss: 0.1215 - output_75_loss: 0.0591 - output_90_loss: 0.0202
# Epoch 4/15
# 2/2 [==============================] - 1s 522ms/step - loss: 0.5146 - output_10_loss: 0.1636 - output_25_loss: 0.1680 - output_50_loss: 0.1110 - output_75_loss: 0.0544 - output_90_loss: 0.0171
# Epoch 5/15
# 2/2 [==============================] - 1s 526ms/step - loss: 0.4409 - output_10_loss: 0.1284 - output_25_loss: 0.1506 - output_50_loss: 0.0992 - output_75_loss: 0.0485 - output_90_loss: 0.0132
# Epoch 6/15
# 2/2 [==============================] - 1s 526ms/step - loss: 0.3583 - output_10_loss: 0.0890 - output_25_loss: 0.1307 - output_50_loss: 0.0861 - output_75_loss: 0.0418 - output_90_loss: 0.0092
# Epoch 7/15
# 2/2 [==============================] - 1s 535ms/step - loss: 0.2772 - output_10_loss: 0.0502 - output_25_loss: 0.1075 - output_50_loss: 0.0717 - output_75_loss: 0.0343 - output_90_loss: 0.0116
# Epoch 8/15
# 2/2 [==============================] - 1s 530ms/step - loss: 0.2109 - output_10_loss: 0.0233 - output_25_loss: 0.0817 - output_50_loss: 0.0551 - output_75_loss: 0.0257 - output_90_loss: 0.0227
# Epoch 9/15
# 2/2 [==============================] - 1s 530ms/step - loss: 0.1582 - output_10_loss: 0.0114 - output_25_loss: 0.0553 - output_50_loss: 0.0353 - output_75_loss: 0.0169 - output_90_loss: 0.0363
# Epoch 10/15
# 2/2 [==============================] - 1s 518ms/step - loss: 0.1242 - output_10_loss: 0.0089 - output_25_loss: 0.0309 - output_50_loss: 0.0184 - output_75_loss: 0.0151 - output_90_loss: 0.0474
# Epoch 11/15
# 2/2 [==============================] - 1s 517ms/step - loss: 0.1156 - output_10_loss: 0.0097 - output_25_loss: 0.0149 - output_50_loss: 0.0151 - output_75_loss: 0.0199 - output_90_loss: 0.0522
# Epoch 12/15
# 2/2 [==============================] - 1s 535ms/step - loss: 0.1157 - output_10_loss: 0.0109 - output_25_loss: 0.0101 - output_50_loss: 0.0217 - output_75_loss: 0.0210 - output_90_loss: 0.0479
# Epoch 13/15
# 2/2 [==============================] - 1s 527ms/step - loss: 0.1074 - output_10_loss: 0.0114 - output_25_loss: 0.0108 - output_50_loss: 0.0276 - output_75_loss: 0.0173 - output_90_loss: 0.0361
# Epoch 14/15
# 2/2 [==============================] - 1s 539ms/step - loss: 0.0904 - output_10_loss: 0.0112 - output_25_loss: 0.0116 - output_50_loss: 0.0282 - output_75_loss: 0.0133 - output_90_loss: 0.0218
# Epoch 15/15
# 2/2 [==============================] - 1s 529ms/step - loss: 0.0728 - output_10_loss: 0.0104 - output_25_loss: 0.0112 - output_50_loss: 0.0240 - output_75_loss: 0.0121 - output_90_loss: 0.0109
# fit complete!
# train_time is: 23.526076316833496 seconds
# 100/100 [==============================] - 5s 40ms/step - loss: 0.0606 - output_10_loss: 0.0093 - output_25_loss: 0.0099 - output_50_loss: 0.0180 - output_75_loss: 0.0129 - output_90_loss: 0.0065
# train_loss is: [0.06058591976761818, 0.009313631802797318, 0.00989982858300209, 0.01797485165297985, 0.01285367552191019, 0.00647684745490551]
# 55/55 [==============================] - 2s 40ms/step - loss: 0.1056 - output_10_loss: 0.0135 - output_25_loss: 0.0194 - output_50_loss: 0.0378 - output_75_loss: 0.0140 - output_90_loss: 0.0169
# test_loss is: [0.10563618689775467, 0.013472712598741055, 0.01942215859889984, 0.037760619074106216, 0.013983507640659809, 0.016930103302001953]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 12 10
# Epoch 1/15
# 2/2 [==============================] - 6s 671ms/step - loss: 0.6986 - output_10_loss: 0.2560 - output_25_loss: 0.2045 - output_50_loss: 0.1407 - output_75_loss: 0.0731 - output_90_loss: 0.0244
# Epoch 2/15
# 2/2 [==============================] - 2s 660ms/step - loss: 0.6491 - output_10_loss: 0.2235 - output_25_loss: 0.1939 - output_50_loss: 0.1334 - output_75_loss: 0.0735 - output_90_loss: 0.0247
# Epoch 3/15
# 2/2 [==============================] - 2s 664ms/step - loss: 0.6003 - output_10_loss: 0.1942 - output_25_loss: 0.1782 - output_50_loss: 0.1292 - output_75_loss: 0.0746 - output_90_loss: 0.0237
# Epoch 4/15
# 2/2 [==============================] - 2s 671ms/step - loss: 0.5455 - output_10_loss: 0.1624 - output_25_loss: 0.1602 - output_50_loss: 0.1252 - output_75_loss: 0.0753 - output_90_loss: 0.0219
# Epoch 5/15
# 2/2 [==============================] - 2s 696ms/step - loss: 0.4812 - output_10_loss: 0.1249 - output_25_loss: 0.1395 - output_50_loss: 0.1205 - output_75_loss: 0.0758 - output_90_loss: 0.0195
# Epoch 6/15
# 2/2 [==============================] - 2s 657ms/step - loss: 0.4049 - output_10_loss: 0.0811 - output_25_loss: 0.1155 - output_50_loss: 0.1147 - output_75_loss: 0.0757 - output_90_loss: 0.0164
# Epoch 7/15
# 2/2 [==============================] - 2s 647ms/step - loss: 0.3200 - output_10_loss: 0.0361 - output_25_loss: 0.0876 - output_50_loss: 0.1072 - output_75_loss: 0.0746 - output_90_loss: 0.0125
# Epoch 8/15
# 2/2 [==============================] - 2s 666ms/step - loss: 0.2456 - output_10_loss: 0.0102 - output_25_loss: 0.0562 - output_50_loss: 0.0969 - output_75_loss: 0.0719 - output_90_loss: 0.0079
# Epoch 9/15
# 2/2 [==============================] - 2s 664ms/step - loss: 0.1953 - output_10_loss: 0.0077 - output_25_loss: 0.0268 - output_50_loss: 0.0828 - output_75_loss: 0.0677 - output_90_loss: 0.0074
# Epoch 10/15
# 2/2 [==============================] - 2s 699ms/step - loss: 0.1744 - output_10_loss: 0.0111 - output_25_loss: 0.0136 - output_50_loss: 0.0643 - output_75_loss: 0.0634 - output_90_loss: 0.0184
# Epoch 11/15
# 2/2 [==============================] - 2s 706ms/step - loss: 0.1607 - output_10_loss: 0.0131 - output_25_loss: 0.0146 - output_50_loss: 0.0447 - output_75_loss: 0.0612 - output_90_loss: 0.0231
# Epoch 12/15
# 2/2 [==============================] - 2s 653ms/step - loss: 0.1399 - output_10_loss: 0.0140 - output_25_loss: 0.0183 - output_50_loss: 0.0282 - output_75_loss: 0.0602 - output_90_loss: 0.0151
# Epoch 13/15
# 2/2 [==============================] - 2s 722ms/step - loss: 0.1219 - output_10_loss: 0.0143 - output_25_loss: 0.0209 - output_50_loss: 0.0168 - output_75_loss: 0.0589 - output_90_loss: 0.0068
# Epoch 14/15
# 2/2 [==============================] - 2s 648ms/step - loss: 0.1117 - output_10_loss: 0.0146 - output_25_loss: 0.0221 - output_50_loss: 0.0113 - output_75_loss: 0.0547 - output_90_loss: 0.0048
# Epoch 15/15
# 2/2 [==============================] - 2s 657ms/step - loss: 0.1034 - output_10_loss: 0.0148 - output_25_loss: 0.0223 - output_50_loss: 0.0105 - output_75_loss: 0.0467 - output_90_loss: 0.0049
# fit complete!
# train_time is: 31.848485946655273 seconds
# 100/100 [==============================] - 5s 40ms/step - loss: 0.0946 - output_10_loss: 0.0151 - output_25_loss: 0.0218 - output_50_loss: 0.0111 - output_75_loss: 0.0372 - output_90_loss: 0.0052
# train_loss is: [0.09461327642202377, 0.015146940015256405, 0.021824819967150688, 0.011065416969358921, 0.03721083328127861, 0.005202127154916525]
# 55/55 [==============================] - 2s 39ms/step - loss: 0.1349 - output_10_loss: 0.0201 - output_25_loss: 0.0363 - output_50_loss: 0.0329 - output_75_loss: 0.0309 - output_90_loss: 0.0105
# test_loss is: [0.1348571926355362, 0.020097272470593452, 0.03633500635623932, 0.03294294700026512, 0.03086792305111885, 0.010450921021401882]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 4 30
# Epoch 1/15
# 2/2 [==============================] - 5s 423ms/step - loss: 0.6066 - output_10_loss: 0.1752 - output_25_loss: 0.2085 - output_50_loss: 0.1241 - output_75_loss: 0.0761 - output_90_loss: 0.0227
# Epoch 2/15
# 2/2 [==============================] - 1s 416ms/step - loss: 0.3834 - output_10_loss: 0.0868 - output_25_loss: 0.1463 - output_50_loss: 0.0603 - output_75_loss: 0.0693 - output_90_loss: 0.0205
# Epoch 3/15
# 2/2 [==============================] - 1s 419ms/step - loss: 0.1744 - output_10_loss: 0.0153 - output_25_loss: 0.0613 - output_50_loss: 0.0208 - output_75_loss: 0.0599 - output_90_loss: 0.0162
# Epoch 4/15
# 2/2 [==============================] - 1s 405ms/step - loss: 0.1227 - output_10_loss: 0.0107 - output_25_loss: 0.0171 - output_50_loss: 0.0432 - output_75_loss: 0.0402 - output_90_loss: 0.0099
# Epoch 5/15
# 2/2 [==============================] - 1s 411ms/step - loss: 0.1296 - output_10_loss: 0.0145 - output_25_loss: 0.0295 - output_50_loss: 0.0561 - output_75_loss: 0.0169 - output_90_loss: 0.0104
# Epoch 6/15
# 2/2 [==============================] - 1s 426ms/step - loss: 0.1391 - output_10_loss: 0.0158 - output_25_loss: 0.0356 - output_50_loss: 0.0521 - output_75_loss: 0.0249 - output_90_loss: 0.0081
# Epoch 7/15
# 2/2 [==============================] - 1s 414ms/step - loss: 0.1196 - output_10_loss: 0.0153 - output_25_loss: 0.0353 - output_50_loss: 0.0352 - output_75_loss: 0.0236 - output_90_loss: 0.0074
# Epoch 8/15
# 2/2 [==============================] - 1s 416ms/step - loss: 0.0855 - output_10_loss: 0.0138 - output_25_loss: 0.0313 - output_50_loss: 0.0158 - output_75_loss: 0.0117 - output_90_loss: 0.0099
# Epoch 9/15
# 2/2 [==============================] - 1s 446ms/step - loss: 0.0877 - output_10_loss: 0.0119 - output_25_loss: 0.0254 - output_50_loss: 0.0230 - output_75_loss: 0.0137 - output_90_loss: 0.0108
# Epoch 10/15
# 2/2 [==============================] - 1s 427ms/step - loss: 0.0950 - output_10_loss: 0.0104 - output_25_loss: 0.0192 - output_50_loss: 0.0340 - output_75_loss: 0.0181 - output_90_loss: 0.0103
# Epoch 11/15
# 2/2 [==============================] - 1s 415ms/step - loss: 0.0864 - output_10_loss: 0.0096 - output_25_loss: 0.0137 - output_50_loss: 0.0326 - output_75_loss: 0.0185 - output_90_loss: 0.0091
# Epoch 12/15
# 2/2 [==============================] - 1s 411ms/step - loss: 0.0689 - output_10_loss: 0.0095 - output_25_loss: 0.0105 - output_50_loss: 0.0230 - output_75_loss: 0.0157 - output_90_loss: 0.0075
# Epoch 13/15
# 2/2 [==============================] - 1s 422ms/step - loss: 0.0515 - output_10_loss: 0.0099 - output_25_loss: 0.0096 - output_50_loss: 0.0130 - output_75_loss: 0.0107 - output_90_loss: 0.0056
# Epoch 14/15
# 2/2 [==============================] - 1s 413ms/step - loss: 0.0466 - output_10_loss: 0.0106 - output_25_loss: 0.0089 - output_50_loss: 0.0132 - output_75_loss: 0.0065 - output_90_loss: 0.0048
# Epoch 15/15
# 2/2 [==============================] - 1s 420ms/step - loss: 0.0507 - output_10_loss: 0.0104 - output_25_loss: 0.0078 - output_50_loss: 0.0172 - output_75_loss: 0.0078 - output_90_loss: 0.0049
# fit complete!
# train_time is: 19.661436557769775 seconds
# 100/100 [==============================] - 5s 40ms/step - loss: 0.0448 - output_10_loss: 0.0093 - output_25_loss: 0.0071 - output_50_loss: 0.0152 - output_75_loss: 0.0068 - output_90_loss: 0.0040
# train_loss is: [0.044772569090127945, 0.009262842126190662, 0.0071006761863827705, 0.015171704813838005, 0.006815759465098381, 0.003971068654209375]
# 55/55 [==============================] - 2s 41ms/step - loss: 0.1443 - output_10_loss: 0.0151 - output_25_loss: 0.0134 - output_50_loss: 0.0421 - output_75_loss: 0.0413 - output_90_loss: 0.0300
# test_loss is: [0.1443362683057785, 0.015064923092722893, 0.013439382426440716, 0.04210815578699112, 0.04130656644701958, 0.029966706410050392]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 8 30
# Epoch 1/15
# 2/2 [==============================] - 6s 537ms/step - loss: 0.6027 - output_10_loss: 0.1946 - output_25_loss: 0.1785 - output_50_loss: 0.1362 - output_75_loss: 0.0681 - output_90_loss: 0.0254
# Epoch 2/15
# 2/2 [==============================] - 1s 545ms/step - loss: 0.3618 - output_10_loss: 0.0747 - output_25_loss: 0.0997 - output_50_loss: 0.1073 - output_75_loss: 0.0610 - output_90_loss: 0.0188
# Epoch 3/15
# 2/2 [==============================] - 1s 554ms/step - loss: 0.1497 - output_10_loss: 0.0068 - output_25_loss: 0.0189 - output_50_loss: 0.0651 - output_75_loss: 0.0464 - output_90_loss: 0.0115
# Epoch 4/15
# 2/2 [==============================] - 1s 533ms/step - loss: 0.1029 - output_10_loss: 0.0141 - output_25_loss: 0.0233 - output_50_loss: 0.0207 - output_75_loss: 0.0219 - output_90_loss: 0.0212
# Epoch 5/15
# 2/2 [==============================] - 1s 535ms/step - loss: 0.1209 - output_10_loss: 0.0176 - output_25_loss: 0.0322 - output_50_loss: 0.0362 - output_75_loss: 0.0171 - output_90_loss: 0.0158
# Epoch 6/15
# 2/2 [==============================] - 1s 544ms/step - loss: 0.1253 - output_10_loss: 0.0182 - output_25_loss: 0.0323 - output_50_loss: 0.0409 - output_75_loss: 0.0228 - output_90_loss: 0.0089
# Epoch 7/15
# 2/2 [==============================] - 1s 541ms/step - loss: 0.0998 - output_10_loss: 0.0176 - output_25_loss: 0.0279 - output_50_loss: 0.0295 - output_75_loss: 0.0094 - output_90_loss: 0.0130
# Epoch 8/15
# 2/2 [==============================] - 1s 538ms/step - loss: 0.0852 - output_10_loss: 0.0163 - output_25_loss: 0.0217 - output_50_loss: 0.0144 - output_75_loss: 0.0144 - output_90_loss: 0.0161
# Epoch 9/15
# 2/2 [==============================] - 1s 612ms/step - loss: 0.0853 - output_10_loss: 0.0149 - output_25_loss: 0.0146 - output_50_loss: 0.0154 - output_75_loss: 0.0206 - output_90_loss: 0.0175
# Epoch 10/15
# 2/2 [==============================] - 1s 561ms/step - loss: 0.0848 - output_10_loss: 0.0137 - output_25_loss: 0.0090 - output_50_loss: 0.0206 - output_75_loss: 0.0220 - output_90_loss: 0.0174
# Epoch 11/15
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0776 - output_10_loss: 0.0129 - output_25_loss: 0.0098 - output_50_loss: 0.0168 - output_75_loss: 0.0198 - output_90_loss: 0.0160
# Epoch 12/15
# 2/2 [==============================] - 1s 543ms/step - loss: 0.0653 - output_10_loss: 0.0130 - output_25_loss: 0.0118 - output_50_loss: 0.0101 - output_75_loss: 0.0145 - output_90_loss: 0.0137
# Epoch 13/15
# 2/2 [==============================] - 1s 539ms/step - loss: 0.0544 - output_10_loss: 0.0135 - output_25_loss: 0.0080 - output_50_loss: 0.0113 - output_75_loss: 0.0086 - output_90_loss: 0.0107
# Epoch 14/15
# 2/2 [==============================] - 1s 576ms/step - loss: 0.0520 - output_10_loss: 0.0137 - output_25_loss: 0.0065 - output_50_loss: 0.0139 - output_75_loss: 0.0079 - output_90_loss: 0.0077
# Epoch 15/15
# 2/2 [==============================] - 1s 531ms/step - loss: 0.0443 - output_10_loss: 0.0130 - output_25_loss: 0.0064 - output_50_loss: 0.0094 - output_75_loss: 0.0078 - output_90_loss: 0.0054
# fit complete!
# train_time is: 24.60357141494751 seconds
# 100/100 [==============================] - 5s 42ms/step - loss: 0.0356 - output_10_loss: 0.0117 - output_25_loss: 0.0053 - output_50_loss: 0.0068 - output_75_loss: 0.0054 - output_90_loss: 0.0043
# train_loss is: [0.03563985228538513, 0.011707928031682968, 0.005321518983691931, 0.006786252837628126, 0.005446151830255985, 0.004255056846886873]
# 55/55 [==============================] - 2s 42ms/step - loss: 0.1197 - output_10_loss: 0.0169 - output_25_loss: 0.0170 - output_50_loss: 0.0255 - output_75_loss: 0.0374 - output_90_loss: 0.0207
# test_loss is: [0.11974596232175827, 0.016942698508501053, 0.017042528837919235, 0.025544099509716034, 0.03740930184721947, 0.02068439871072769]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 12 30
# Epoch 1/15
# 2/2 [==============================] - 6s 705ms/step - loss: 0.6594 - output_10_loss: 0.2859 - output_25_loss: 0.1747 - output_50_loss: 0.1094 - output_75_loss: 0.0696 - output_90_loss: 0.0196
# Epoch 2/15
# 2/2 [==============================] - 2s 691ms/step - loss: 0.5088 - output_10_loss: 0.2089 - output_25_loss: 0.1372 - output_50_loss: 0.0840 - output_75_loss: 0.0648 - output_90_loss: 0.0136
# Epoch 3/15
# 2/2 [==============================] - 2s 676ms/step - loss: 0.3326 - output_10_loss: 0.1301 - output_25_loss: 0.0850 - output_50_loss: 0.0490 - output_75_loss: 0.0584 - output_90_loss: 0.0090
# Epoch 4/15
# 2/2 [==============================] - 2s 670ms/step - loss: 0.1563 - output_10_loss: 0.0429 - output_25_loss: 0.0247 - output_50_loss: 0.0189 - output_75_loss: 0.0473 - output_90_loss: 0.0207
# Epoch 5/15
# 2/2 [==============================] - 2s 679ms/step - loss: 0.1154 - output_10_loss: 0.0070 - output_25_loss: 0.0171 - output_50_loss: 0.0306 - output_75_loss: 0.0320 - output_90_loss: 0.0262
# Epoch 6/15
# 2/2 [==============================] - 2s 663ms/step - loss: 0.0989 - output_10_loss: 0.0112 - output_25_loss: 0.0262 - output_50_loss: 0.0330 - output_75_loss: 0.0152 - output_90_loss: 0.0105
# Epoch 7/15
# 2/2 [==============================] - 2s 690ms/step - loss: 0.0867 - output_10_loss: 0.0138 - output_25_loss: 0.0291 - output_50_loss: 0.0222 - output_75_loss: 0.0107 - output_90_loss: 0.0079
# Epoch 8/15
# 2/2 [==============================] - 2s 673ms/step - loss: 0.0876 - output_10_loss: 0.0148 - output_25_loss: 0.0280 - output_50_loss: 0.0143 - output_75_loss: 0.0150 - output_90_loss: 0.0124
# Epoch 9/15
# 2/2 [==============================] - 2s 671ms/step - loss: 0.0915 - output_10_loss: 0.0149 - output_25_loss: 0.0249 - output_50_loss: 0.0226 - output_75_loss: 0.0107 - output_90_loss: 0.0153
# Epoch 10/15
# 2/2 [==============================] - 2s 675ms/step - loss: 0.0856 - output_10_loss: 0.0148 - output_25_loss: 0.0207 - output_50_loss: 0.0231 - output_75_loss: 0.0077 - output_90_loss: 0.0162
# Epoch 11/15
# 2/2 [==============================] - 2s 665ms/step - loss: 0.0712 - output_10_loss: 0.0147 - output_25_loss: 0.0159 - output_50_loss: 0.0144 - output_75_loss: 0.0077 - output_90_loss: 0.0155
# Epoch 12/15
# 2/2 [==============================] - 2s 661ms/step - loss: 0.0578 - output_10_loss: 0.0147 - output_25_loss: 0.0106 - output_50_loss: 0.0082 - output_75_loss: 0.0074 - output_90_loss: 0.0138
# Epoch 13/15
# 2/2 [==============================] - 2s 657ms/step - loss: 0.0571 - output_10_loss: 0.0146 - output_25_loss: 0.0082 - output_50_loss: 0.0127 - output_75_loss: 0.0068 - output_90_loss: 0.0118
# Epoch 14/15
# 2/2 [==============================] - 2s 688ms/step - loss: 0.0596 - output_10_loss: 0.0142 - output_25_loss: 0.0121 - output_50_loss: 0.0139 - output_75_loss: 0.0064 - output_90_loss: 0.0101
# Epoch 15/15
# 2/2 [==============================] - 2s 666ms/step - loss: 0.0543 - output_10_loss: 0.0137 - output_25_loss: 0.0128 - output_50_loss: 0.0102 - output_75_loss: 0.0062 - output_90_loss: 0.0086
# fit complete!
# train_time is: 32.72091341018677 seconds
# 100/100 [==============================] - 5s 42ms/step - loss: 0.0446 - output_10_loss: 0.0132 - output_25_loss: 0.0086 - output_50_loss: 0.0067 - output_75_loss: 0.0061 - output_90_loss: 0.0074
# train_loss is: [0.04459257796406746, 0.013161995448172092, 0.008613085374236107, 0.006691501941531897, 0.0061341444961726665, 0.007368907332420349]
# 55/55 [==============================] - 2s 43ms/step - loss: 0.0883 - output_10_loss: 0.0175 - output_25_loss: 0.0131 - output_50_loss: 0.0230 - output_75_loss: 0.0207 - output_90_loss: 0.0114
# test_loss is: [0.08831974118947983, 0.017479337751865387, 0.013144362717866898, 0.02296496368944645, 0.020738277584314346, 0.011369859799742699]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 4 50
# Epoch 1/15
# 2/2 [==============================] - 6s 427ms/step - loss: 0.6730 - output_10_loss: 0.2617 - output_25_loss: 0.1887 - output_50_loss: 0.1298 - output_75_loss: 0.0661 - output_90_loss: 0.0266
# Epoch 2/15
# 2/2 [==============================] - 1s 439ms/step - loss: 0.3505 - output_10_loss: 0.1278 - output_25_loss: 0.1048 - output_50_loss: 0.0479 - output_75_loss: 0.0492 - output_90_loss: 0.0204
# Epoch 3/15
# 2/2 [==============================] - 1s 428ms/step - loss: 0.1051 - output_10_loss: 0.0100 - output_25_loss: 0.0180 - output_50_loss: 0.0391 - output_75_loss: 0.0266 - output_90_loss: 0.0101
# Epoch 4/15
# 2/2 [==============================] - 1s 432ms/step - loss: 0.1652 - output_10_loss: 0.0139 - output_25_loss: 0.0311 - output_50_loss: 0.0724 - output_75_loss: 0.0253 - output_90_loss: 0.0202
# Epoch 5/15
# 2/2 [==============================] - 1s 403ms/step - loss: 0.1487 - output_10_loss: 0.0163 - output_25_loss: 0.0353 - output_50_loss: 0.0660 - output_75_loss: 0.0200 - output_90_loss: 0.0084
# Epoch 6/15
# 2/2 [==============================] - 1s 403ms/step - loss: 0.1155 - output_10_loss: 0.0165 - output_25_loss: 0.0310 - output_50_loss: 0.0393 - output_75_loss: 0.0173 - output_90_loss: 0.0085
# Epoch 7/15
# 2/2 [==============================] - 1s 419ms/step - loss: 0.0924 - output_10_loss: 0.0158 - output_25_loss: 0.0225 - output_50_loss: 0.0148 - output_75_loss: 0.0242 - output_90_loss: 0.0122
# Epoch 8/15
# 2/2 [==============================] - 1s 413ms/step - loss: 0.1021 - output_10_loss: 0.0148 - output_25_loss: 0.0136 - output_50_loss: 0.0337 - output_75_loss: 0.0235 - output_90_loss: 0.0135
# Epoch 9/15
# 2/2 [==============================] - 1s 405ms/step - loss: 0.0874 - output_10_loss: 0.0141 - output_25_loss: 0.0088 - output_50_loss: 0.0323 - output_75_loss: 0.0159 - output_90_loss: 0.0132
# Epoch 10/15
# 2/2 [==============================] - 1s 398ms/step - loss: 0.0599 - output_10_loss: 0.0140 - output_25_loss: 0.0074 - output_50_loss: 0.0152 - output_75_loss: 0.0084 - output_90_loss: 0.0119
# Epoch 11/15
# 2/2 [==============================] - 1s 408ms/step - loss: 0.0617 - output_10_loss: 0.0140 - output_25_loss: 0.0064 - output_50_loss: 0.0123 - output_75_loss: 0.0160 - output_90_loss: 0.0099
# Epoch 12/15
# 2/2 [==============================] - 1s 422ms/step - loss: 0.0585 - output_10_loss: 0.0133 - output_25_loss: 0.0085 - output_50_loss: 0.0156 - output_75_loss: 0.0097 - output_90_loss: 0.0082
# Epoch 13/15
# 2/2 [==============================] - 1s 412ms/step - loss: 0.0479 - output_10_loss: 0.0121 - output_25_loss: 0.0095 - output_50_loss: 0.0107 - output_75_loss: 0.0062 - output_90_loss: 0.0065
# Epoch 14/15
# 2/2 [==============================] - 1s 439ms/step - loss: 0.0378 - output_10_loss: 0.0109 - output_25_loss: 0.0046 - output_50_loss: 0.0070 - output_75_loss: 0.0077 - output_90_loss: 0.0047
# Epoch 15/15
# 2/2 [==============================] - 1s 410ms/step - loss: 0.0386 - output_10_loss: 0.0098 - output_25_loss: 0.0078 - output_50_loss: 0.0072 - output_75_loss: 0.0068 - output_90_loss: 0.0042
# fit complete!
# train_time is: 20.213627338409424 seconds
# 100/100 [==============================] - 5s 42ms/step - loss: 0.0402 - output_10_loss: 0.0086 - output_25_loss: 0.0098 - output_50_loss: 0.0079 - output_75_loss: 0.0058 - output_90_loss: 0.0054
# train_loss is: [0.04021739587187767, 0.008607450872659683, 0.009820851497352123, 0.007866499945521355, 0.005817305762320757, 0.005380097310990095]
# 55/55 [==============================] - 2s 43ms/step - loss: 0.0891 - output_10_loss: 0.0122 - output_25_loss: 0.0184 - output_50_loss: 0.0153 - output_75_loss: 0.0194 - output_90_loss: 0.0211
# test_loss is: [0.08912810683250427, 0.012185074388980865, 0.018408184871077538, 0.01528632827103138, 0.01938958652317524, 0.02113373391330242]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 8 50
# Epoch 1/15
# 2/2 [==============================] - 6s 576ms/step - loss: 0.7359 - output_10_loss: 0.2718 - output_25_loss: 0.2067 - output_50_loss: 0.1581 - output_75_loss: 0.0704 - output_90_loss: 0.0289
# Epoch 2/15
# 2/2 [==============================] - 1s 564ms/step - loss: 0.4469 - output_10_loss: 0.1278 - output_25_loss: 0.1121 - output_50_loss: 0.1117 - output_75_loss: 0.0691 - output_90_loss: 0.0257
# Epoch 3/15
# 2/2 [==============================] - 1s 556ms/step - loss: 0.1925 - output_10_loss: 0.0134 - output_25_loss: 0.0263 - output_50_loss: 0.0716 - output_75_loss: 0.0589 - output_90_loss: 0.0209
# Epoch 4/15
# 2/2 [==============================] - 1s 551ms/step - loss: 0.1073 - output_10_loss: 0.0122 - output_25_loss: 0.0240 - output_50_loss: 0.0205 - output_75_loss: 0.0352 - output_90_loss: 0.0132
# Epoch 5/15
# 2/2 [==============================] - 1s 559ms/step - loss: 0.1137 - output_10_loss: 0.0174 - output_25_loss: 0.0377 - output_50_loss: 0.0334 - output_75_loss: 0.0134 - output_90_loss: 0.0088
# Epoch 6/15
# 2/2 [==============================] - 1s 555ms/step - loss: 0.1509 - output_10_loss: 0.0192 - output_25_loss: 0.0414 - output_50_loss: 0.0451 - output_75_loss: 0.0296 - output_90_loss: 0.0120
# Epoch 7/15
# 2/2 [==============================] - 1s 563ms/step - loss: 0.1189 - output_10_loss: 0.0192 - output_25_loss: 0.0397 - output_50_loss: 0.0361 - output_75_loss: 0.0136 - output_90_loss: 0.0064
# Epoch 8/15
# 2/2 [==============================] - 1s 557ms/step - loss: 0.0963 - output_10_loss: 0.0184 - output_25_loss: 0.0351 - output_50_loss: 0.0168 - output_75_loss: 0.0128 - output_90_loss: 0.0092
# Epoch 9/15
# 2/2 [==============================] - 1s 559ms/step - loss: 0.0933 - output_10_loss: 0.0175 - output_25_loss: 0.0281 - output_50_loss: 0.0137 - output_75_loss: 0.0192 - output_90_loss: 0.0108
# Epoch 10/15
# 2/2 [==============================] - 1s 570ms/step - loss: 0.0969 - output_10_loss: 0.0167 - output_25_loss: 0.0203 - output_50_loss: 0.0262 - output_75_loss: 0.0194 - output_90_loss: 0.0104
# Epoch 11/15
# 2/2 [==============================] - 1s 573ms/step - loss: 0.0820 - output_10_loss: 0.0160 - output_25_loss: 0.0125 - output_50_loss: 0.0258 - output_75_loss: 0.0154 - output_90_loss: 0.0084
# Epoch 12/15
# 2/2 [==============================] - 1s 585ms/step - loss: 0.0587 - output_10_loss: 0.0156 - output_25_loss: 0.0080 - output_50_loss: 0.0162 - output_75_loss: 0.0093 - output_90_loss: 0.0058
# Epoch 13/15
# 2/2 [==============================] - 1s 573ms/step - loss: 0.0516 - output_10_loss: 0.0155 - output_25_loss: 0.0109 - output_50_loss: 0.0087 - output_75_loss: 0.0076 - output_90_loss: 0.0050
# Epoch 14/15
# 2/2 [==============================] - 1s 559ms/step - loss: 0.0608 - output_10_loss: 0.0152 - output_25_loss: 0.0096 - output_50_loss: 0.0142 - output_75_loss: 0.0110 - output_90_loss: 0.0071
# Epoch 15/15
# 2/2 [==============================] - 1s 570ms/step - loss: 0.0502 - output_10_loss: 0.0139 - output_25_loss: 0.0068 - output_50_loss: 0.0148 - output_75_loss: 0.0063 - output_90_loss: 0.0047
# fit complete!
# train_time is: 25.47482466697693 seconds
# 100/100 [==============================] - 5s 45ms/step - loss: 0.0428 - output_10_loss: 0.0122 - output_25_loss: 0.0058 - output_50_loss: 0.0101 - output_75_loss: 0.0070 - output_90_loss: 0.0044
# train_loss is: [0.04281836375594139, 0.012169050052762032, 0.0057923030108213425, 0.010078413411974907, 0.007045902777463198, 0.0043586427345871925]
# 55/55 [==============================] - 2s 43ms/step - loss: 0.1064 - output_10_loss: 0.0170 - output_25_loss: 0.0167 - output_50_loss: 0.0335 - output_75_loss: 0.0206 - output_90_loss: 0.0152
# test_loss is: [0.10639968514442444, 0.01699470914900303, 0.01673027127981186, 0.033488065004348755, 0.02059103175997734, 0.015221541747450829]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.01 12 50
# Epoch 1/15
# 2/2 [==============================] - 6s 716ms/step - loss: 0.6742 - output_10_loss: 0.2178 - output_25_loss: 0.2315 - output_50_loss: 0.1285 - output_75_loss: 0.0686 - output_90_loss: 0.0276
# Epoch 2/15
# 2/2 [==============================] - 2s 684ms/step - loss: 0.4116 - output_10_loss: 0.1193 - output_25_loss: 0.1459 - output_50_loss: 0.0737 - output_75_loss: 0.0487 - output_90_loss: 0.0236
# Epoch 3/15
# 2/2 [==============================] - 2s 687ms/step - loss: 0.1106 - output_10_loss: 0.0101 - output_25_loss: 0.0428 - output_50_loss: 0.0180 - output_75_loss: 0.0218 - output_90_loss: 0.0165
# Epoch 4/15
# 2/2 [==============================] - 2s 679ms/step - loss: 0.1334 - output_10_loss: 0.0142 - output_25_loss: 0.0239 - output_50_loss: 0.0585 - output_75_loss: 0.0284 - output_90_loss: 0.0061
# Epoch 5/15
# 2/2 [==============================] - 2s 687ms/step - loss: 0.1548 - output_10_loss: 0.0176 - output_25_loss: 0.0350 - output_50_loss: 0.0658 - output_75_loss: 0.0199 - output_90_loss: 0.0137
# Epoch 6/15
# 2/2 [==============================] - 2s 693ms/step - loss: 0.1255 - output_10_loss: 0.0175 - output_25_loss: 0.0347 - output_50_loss: 0.0507 - output_75_loss: 0.0153 - output_90_loss: 0.0043
# Epoch 7/15
# 2/2 [==============================] - 2s 699ms/step - loss: 0.1059 - output_10_loss: 0.0165 - output_25_loss: 0.0294 - output_50_loss: 0.0240 - output_75_loss: 0.0255 - output_90_loss: 0.0075
# Epoch 8/15
# 2/2 [==============================] - 2s 682ms/step - loss: 0.0899 - output_10_loss: 0.0151 - output_25_loss: 0.0202 - output_50_loss: 0.0148 - output_75_loss: 0.0272 - output_90_loss: 0.0097
# Epoch 9/15
# 2/2 [==============================] - 2s 703ms/step - loss: 0.0918 - output_10_loss: 0.0139 - output_25_loss: 0.0112 - output_50_loss: 0.0310 - output_75_loss: 0.0226 - output_90_loss: 0.0102
# Epoch 10/15
# 2/2 [==============================] - 2s 664ms/step - loss: 0.0785 - output_10_loss: 0.0135 - output_25_loss: 0.0081 - output_50_loss: 0.0302 - output_75_loss: 0.0144 - output_90_loss: 0.0094
# Epoch 11/15
# 2/2 [==============================] - 2s 653ms/step - loss: 0.0557 - output_10_loss: 0.0141 - output_25_loss: 0.0077 - output_50_loss: 0.0163 - output_75_loss: 0.0073 - output_90_loss: 0.0074
# Epoch 12/15
# 2/2 [==============================] - 2s 678ms/step - loss: 0.0565 - output_10_loss: 0.0149 - output_25_loss: 0.0061 - output_50_loss: 0.0101 - output_75_loss: 0.0176 - output_90_loss: 0.0048
# Epoch 13/15
# 2/2 [==============================] - 2s 669ms/step - loss: 0.0536 - output_10_loss: 0.0144 - output_25_loss: 0.0053 - output_50_loss: 0.0141 - output_75_loss: 0.0135 - output_90_loss: 0.0035
# Epoch 14/15
# 2/2 [==============================] - 2s 676ms/step - loss: 0.0402 - output_10_loss: 0.0125 - output_25_loss: 0.0068 - output_50_loss: 0.0089 - output_75_loss: 0.0060 - output_90_loss: 0.0034
# Epoch 15/15
# 2/2 [==============================] - 2s 662ms/step - loss: 0.0395 - output_10_loss: 0.0107 - output_25_loss: 0.0051 - output_50_loss: 0.0065 - output_75_loss: 0.0113 - output_90_loss: 0.0033
# fit complete!
# train_time is: 32.967406272888184 seconds
# 100/100 [==============================] - 5s 41ms/step - loss: 0.0401 - output_10_loss: 0.0097 - output_25_loss: 0.0047 - output_50_loss: 0.0063 - output_75_loss: 0.0130 - output_90_loss: 0.0039
# train_loss is: [0.040056075900793076, 0.00971822626888752, 0.004709190223366022, 0.0062568457797169685, 0.01301957480609417, 0.0038618065882474184]
# 55/55 [==============================] - 2s 42ms/step - loss: 0.0753 - output_10_loss: 0.0129 - output_25_loss: 0.0135 - output_50_loss: 0.0184 - output_75_loss: 0.0093 - output_90_loss: 0.0188
# test_loss is: [0.07530420273542404, 0.012855038046836853, 0.013473667204380035, 0.018423477187752724, 0.009297930635511875, 0.018763665109872818]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.1 4 10
# Epoch 1/15
# 2/2 [==============================] - 5s 411ms/step - loss: 0.7230 - output_10_loss: 0.2498 - output_25_loss: 0.2220 - output_50_loss: 0.1463 - output_75_loss: 0.0811 - output_90_loss: 0.0234
# Epoch 2/15
# 2/2 [==============================] - 1s 405ms/step - loss: 0.1573 - output_10_loss: 0.0175 - output_25_loss: 0.0314 - output_50_loss: 0.0401 - output_75_loss: 0.0283 - output_90_loss: 0.0341
# Epoch 3/15
# 2/2 [==============================] - 1s 410ms/step - loss: 0.1708 - output_10_loss: 0.0199 - output_25_loss: 0.0363 - output_50_loss: 0.0331 - output_75_loss: 0.0441 - output_90_loss: 0.0260
# Epoch 4/15
# 2/2 [==============================] - 1s 412ms/step - loss: 0.1099 - output_10_loss: 0.0170 - output_25_loss: 0.0249 - output_50_loss: 0.0150 - output_75_loss: 0.0218 - output_90_loss: 0.0173
# Epoch 5/15
# 2/2 [==============================] - 1s 423ms/step - loss: 0.1282 - output_10_loss: 0.0138 - output_25_loss: 0.0127 - output_50_loss: 0.0250 - output_75_loss: 0.0362 - output_90_loss: 0.0254
# Epoch 6/15
# 2/2 [==============================] - 1s 419ms/step - loss: 0.1121 - output_10_loss: 0.0122 - output_25_loss: 0.0083 - output_50_loss: 0.0127 - output_75_loss: 0.0352 - output_90_loss: 0.0278
# Epoch 7/15
# 2/2 [==============================] - 1s 414ms/step - loss: 0.1012 - output_10_loss: 0.0125 - output_25_loss: 0.0059 - output_50_loss: 0.0114 - output_75_loss: 0.0270 - output_90_loss: 0.0280
# Epoch 8/15
# 2/2 [==============================] - 1s 410ms/step - loss: 0.0978 - output_10_loss: 0.0123 - output_25_loss: 0.0047 - output_50_loss: 0.0206 - output_75_loss: 0.0167 - output_90_loss: 0.0272
# Epoch 9/15
# 2/2 [==============================] - 1s 429ms/step - loss: 0.0800 - output_10_loss: 0.0106 - output_25_loss: 0.0044 - output_50_loss: 0.0168 - output_75_loss: 0.0073 - output_90_loss: 0.0255
# Epoch 10/15
# 2/2 [==============================] - 1s 425ms/step - loss: 0.0615 - output_10_loss: 0.0077 - output_25_loss: 0.0042 - output_50_loss: 0.0074 - output_75_loss: 0.0051 - output_90_loss: 0.0232
# Epoch 11/15
# 2/2 [==============================] - 1s 416ms/step - loss: 0.0587 - output_10_loss: 0.0044 - output_25_loss: 0.0032 - output_50_loss: 0.0098 - output_75_loss: 0.0085 - output_90_loss: 0.0208
# Epoch 12/15
# 2/2 [==============================] - 1s 424ms/step - loss: 0.0528 - output_10_loss: 0.0033 - output_25_loss: 0.0032 - output_50_loss: 0.0129 - output_75_loss: 0.0049 - output_90_loss: 0.0181
# Epoch 13/15
# 2/2 [==============================] - 1s 395ms/step - loss: 0.0422 - output_10_loss: 0.0028 - output_25_loss: 0.0048 - output_50_loss: 0.0076 - output_75_loss: 0.0031 - output_90_loss: 0.0148
# Epoch 14/15
# 2/2 [==============================] - 1s 416ms/step - loss: 0.0373 - output_10_loss: 0.0022 - output_25_loss: 0.0060 - output_50_loss: 0.0059 - output_75_loss: 0.0039 - output_90_loss: 0.0106
# Epoch 15/15
# 2/2 [==============================] - 1s 407ms/step - loss: 0.0327 - output_10_loss: 0.0021 - output_25_loss: 0.0040 - output_50_loss: 0.0082 - output_75_loss: 0.0035 - output_90_loss: 0.0080
# fit complete!
# train_time is: 19.499319076538086 seconds
# 100/100 [==============================] - 5s 41ms/step - loss: 0.0255 - output_10_loss: 0.0013 - output_25_loss: 0.0040 - output_50_loss: 0.0047 - output_75_loss: 0.0041 - output_90_loss: 0.0061
# train_loss is: [0.02554647997021675, 0.001300332834944129, 0.0039623817428946495, 0.004662704654037952, 0.004076950717717409, 0.006109553389251232]
# 55/55 [==============================] - 2s 39ms/step - loss: 0.0556 - output_10_loss: 0.0039 - output_25_loss: 0.0079 - output_50_loss: 0.0186 - output_75_loss: 0.0151 - output_90_loss: 0.0046
# test_loss is: [0.055607084184885025, 0.0039173574186861515, 0.007945063523948193, 0.01857536844909191, 0.015127088874578476, 0.004607643000781536]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.1 8 10
# Epoch 1/15
# 2/2 [==============================] - 5s 538ms/step - loss: 0.5825 - output_10_loss: 0.1733 - output_25_loss: 0.1984 - output_50_loss: 0.1182 - output_75_loss: 0.0690 - output_90_loss: 0.0223
# Epoch 2/15
# 2/2 [==============================] - 1s 551ms/step - loss: 0.2681 - output_10_loss: 0.0150 - output_25_loss: 0.0316 - output_50_loss: 0.0734 - output_75_loss: 0.0354 - output_90_loss: 0.1041
# Epoch 3/15
# 2/2 [==============================] - 1s 538ms/step - loss: 0.1751 - output_10_loss: 0.0169 - output_25_loss: 0.0305 - output_50_loss: 0.0637 - output_75_loss: 0.0228 - output_90_loss: 0.0282
# Epoch 4/15
# 2/2 [==============================] - 1s 522ms/step - loss: 0.1123 - output_10_loss: 0.0111 - output_25_loss: 0.0149 - output_50_loss: 0.0209 - output_75_loss: 0.0287 - output_90_loss: 0.0233
# Epoch 5/15
# 2/2 [==============================] - 1s 534ms/step - loss: 0.1224 - output_10_loss: 0.0075 - output_25_loss: 0.0108 - output_50_loss: 0.0394 - output_75_loss: 0.0187 - output_90_loss: 0.0332
# Epoch 6/15
# 2/2 [==============================] - 1s 535ms/step - loss: 0.0994 - output_10_loss: 0.0071 - output_25_loss: 0.0090 - output_50_loss: 0.0236 - output_75_loss: 0.0105 - output_90_loss: 0.0372
# Epoch 7/15
# 2/2 [==============================] - 1s 526ms/step - loss: 0.0832 - output_10_loss: 0.0080 - output_25_loss: 0.0064 - output_50_loss: 0.0101 - output_75_loss: 0.0104 - output_90_loss: 0.0376
# Epoch 8/15
# 2/2 [==============================] - 1s 536ms/step - loss: 0.0801 - output_10_loss: 0.0064 - output_25_loss: 0.0085 - output_50_loss: 0.0161 - output_75_loss: 0.0057 - output_90_loss: 0.0343
# Epoch 9/15
# 2/2 [==============================] - 1s 542ms/step - loss: 0.0573 - output_10_loss: 0.0029 - output_25_loss: 0.0031 - output_50_loss: 0.0070 - output_75_loss: 0.0054 - output_90_loss: 0.0311
# Epoch 10/15
# 2/2 [==============================] - 1s 532ms/step - loss: 0.0525 - output_10_loss: 0.0035 - output_25_loss: 0.0053 - output_50_loss: 0.0065 - output_75_loss: 0.0031 - output_90_loss: 0.0272
# Epoch 11/15
# 2/2 [==============================] - 1s 567ms/step - loss: 0.0422 - output_10_loss: 0.0031 - output_25_loss: 0.0047 - output_50_loss: 0.0032 - output_75_loss: 0.0030 - output_90_loss: 0.0219
# Epoch 12/15
# 2/2 [==============================] - 1s 542ms/step - loss: 0.0377 - output_10_loss: 0.0045 - output_25_loss: 0.0047 - output_50_loss: 0.0040 - output_75_loss: 0.0030 - output_90_loss: 0.0161
# Epoch 13/15
# 2/2 [==============================] - 1s 524ms/step - loss: 0.0327 - output_10_loss: 0.0051 - output_25_loss: 0.0023 - output_50_loss: 0.0052 - output_75_loss: 0.0038 - output_90_loss: 0.0117
# Epoch 14/15
# 2/2 [==============================] - 1s 522ms/step - loss: 0.0280 - output_10_loss: 0.0045 - output_25_loss: 0.0033 - output_50_loss: 0.0046 - output_75_loss: 0.0036 - output_90_loss: 0.0080
# Epoch 15/15
# 2/2 [==============================] - 1s 530ms/step - loss: 0.0245 - output_10_loss: 0.0033 - output_25_loss: 0.0033 - output_50_loss: 0.0055 - output_75_loss: 0.0037 - output_90_loss: 0.0051
# fit complete!
# train_time is: 24.131649017333984 seconds
# 100/100 [==============================] - 5s 43ms/step - loss: 0.0197 - output_10_loss: 0.0027 - output_25_loss: 0.0032 - output_50_loss: 0.0041 - output_75_loss: 0.0033 - output_90_loss: 0.0029
# train_loss is: [0.01967429928481579, 0.0027282738592475653, 0.003195407334715128, 0.004130130633711815, 0.0033392824698239565, 0.0029358428437262774]
# 55/55 [==============================] - 2s 43ms/step - loss: 0.0818 - output_10_loss: 0.0067 - output_25_loss: 0.0119 - output_50_loss: 0.0182 - output_75_loss: 0.0219 - output_90_loss: 0.0198
# test_loss is: [0.0818345695734024, 0.006708057597279549, 0.011880874633789062, 0.018210668116807938, 0.021876487880945206, 0.019813114777207375]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.1 12 10
# Epoch 1/15
# 2/2 [==============================] - 6s 681ms/step - loss: 0.5446 - output_10_loss: 0.1463 - output_25_loss: 0.1630 - output_50_loss: 0.1093 - output_75_loss: 0.0979 - output_90_loss: 0.0271
# Epoch 2/15
# 2/2 [==============================] - 2s 660ms/step - loss: 0.2709 - output_10_loss: 0.0156 - output_25_loss: 0.0290 - output_50_loss: 0.0755 - output_75_loss: 0.0672 - output_90_loss: 0.0771
# Epoch 3/15
# 2/2 [==============================] - 2s 645ms/step - loss: 0.1641 - output_10_loss: 0.0127 - output_25_loss: 0.0224 - output_50_loss: 0.0636 - output_75_loss: 0.0309 - output_90_loss: 0.0254
# Epoch 4/15
# 2/2 [==============================] - 2s 692ms/step - loss: 0.0905 - output_10_loss: 0.0099 - output_25_loss: 0.0097 - output_50_loss: 0.0283 - output_75_loss: 0.0105 - output_90_loss: 0.0251
# Epoch 5/15
# ...
# Epoch 15/15
# 2/2 [==============================] - 2s 703ms/step - loss: 0.0804 - output_10_loss: 0.0068 - output_25_loss: 0.0120 - output_50_loss: 0.0200 - output_75_loss: 0.0224 - output_90_loss: 0.0156
# fit complete!
# train_time is: 34.10807180404663 seconds
# 100/100 [==============================] - 8s 73ms/step - loss: 0.0712 - output_10_loss: 0.0064 - output_25_loss: 0.0109 - output_50_loss: 0.0178 - output_75_loss: 0.0186 - output_90_loss: 0.0145
# train_loss is: [0.07116951793432236, 0.006365261506289244, 0.010940696112811565, 0.01778866909444332, 0.018560798838734627, 0.01449082512408495]
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0506 - output_10_loss: 0.0066 - output_25_loss: 0.0075 - output_50_loss: 0.0135 - output_75_loss: 0.0106 - output_90_loss: 0.0093
# test_loss is: [0.05060075595974922, 0.006596706807613373, 0.00750363664701581, 0.013535985723137856, 0.010643746703863144, 0.009297417476773262]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.1 4 50
# Epoch 1/15
# 2/2 [==============================] - 5s 436ms/step - loss: 0.5315 - output_10_loss: 0.1429 - output_25_loss: 0.1406 - output_50_loss: 0.1007 - output_75_loss: 0.0782 - output_90_loss: 0.0663
# Epoch 2/15
# 2/2 [==============================] - 1s 492ms/step - loss: 0.5687 - output_10_loss: 0.0275 - output_25_loss: 0.0687 - output_50_loss: 0.1374 - output_75_loss: 0.1216 - output_90_loss: 0.1921
# Epoch 3/15
# 2/2 [==============================] - 1s 435ms/step - loss: 0.4978 - output_10_loss: 0.0275 - output_25_loss: 0.0687 - output_50_loss: 0.1374 - output_75_loss: 0.2017 - output_90_loss: 0.0358
# Epoch 4/15
# 2/2 [==============================] - 1s 441ms/step - loss: 0.6388 - output_10_loss: 0.0275 - output_25_loss: 0.0687 - output_50_loss: 0.1374 - output_75_loss: 0.2058 - output_90_loss: 0.1732
# Epoch 5/15
# 2/2 [==============================] - 1s 474ms/step - loss: 0.4949 - output_10_loss: 0.0274 - output_25_loss: 0.0686 - output_50_loss: 0.1369 - output_75_loss: 0.2044 - output_90_loss: 0.0332
# Epoch 6/15
# 2/2 [==============================] - 1s 452ms/step - loss: 0.4739 - output_10_loss: 0.0262 - output_25_loss: 0.0658 - output_50_loss: 0.1263 - output_75_loss: 0.1882 - output_90_loss: 0.0452
# Epoch 7/15
# 2/2 [==============================] - 1s 450ms/step - loss: 0.2602 - output_10_loss: 0.0157 - output_25_loss: 0.0395 - output_50_loss: 0.0586 - output_75_loss: 0.0968 - output_90_loss: 0.0291
# Epoch 8/15
# 2/2 [==============================] - 1s 466ms/step - loss: 0.1317 - output_10_loss: 0.0152 - output_25_loss: 0.0184 - output_50_loss: 0.0326 - output_75_loss: 0.0233 - output_90_loss: 0.0186
# Epoch 9/15
# 2/2 [==============================] - 1s 446ms/step - loss: 0.1370 - output_10_loss: 0.0100 - output_25_loss: 0.0244 - output_50_loss: 0.0246 - output_75_loss: 0.0309 - output_90_loss: 0.0165
# Epoch 10/15
# 2/2 [==============================] - 1s 439ms/step - loss: 0.1532 - output_10_loss: 0.0133 - output_25_loss: 0.0291 - output_50_loss: 0.0295 - output_75_loss: 0.0281 - output_90_loss: 0.0193
# Epoch 11/15
# 2/2 [==============================] - 1s 443ms/step - loss: 0.1347 - output_10_loss: 0.0122 - output_25_loss: 0.0221 - output_50_loss: 0.0234 - output_75_loss: 0.0254 - output_90_loss: 0.0183
# Epoch 12/15
# 2/2 [==============================] - 1s 453ms/step - loss: 0.1245 - output_10_loss: 0.0100 - output_25_loss: 0.0175 - output_50_loss: 0.0222 - output_75_loss: 0.0261 - output_90_loss: 0.0182
# Epoch 13/15
# 2/2 [==============================] - 1s 457ms/step - loss: 0.1222 - output_10_loss: 0.0098 - output_25_loss: 0.0142 - output_50_loss: 0.0278 - output_75_loss: 0.0231 - output_90_loss: 0.0198
# Epoch 14/15
# 2/2 [==============================] - 1s 459ms/step - loss: 0.1211 - output_10_loss: 0.0080 - output_25_loss: 0.0163 - output_50_loss: 0.0279 - output_75_loss: 0.0261 - output_90_loss: 0.0190
# Epoch 15/15
# 2/2 [==============================] - 1s 448ms/step - loss: 0.1063 - output_10_loss: 0.0065 - output_25_loss: 0.0143 - output_50_loss: 0.0226 - output_75_loss: 0.0254 - output_90_loss: 0.0171
# fit complete!
# train_time is: 21.2854483127594 seconds
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1035 - output_10_loss: 0.0075 - output_25_loss: 0.0181 - output_50_loss: 0.0203 - output_75_loss: 0.0236 - output_90_loss: 0.0158
# train_loss is: [0.10347625613212585, 0.007474042475223541, 0.01808846741914749, 0.020299797877669334, 0.02360679768025875, 0.015779882669448853]
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0672 - output_10_loss: 0.0043 - output_25_loss: 0.0102 - output_50_loss: 0.0120 - output_75_loss: 0.0108 - output_90_loss: 0.0116
# test_loss is: [0.06717154383659363, 0.0043130419217050076, 0.010186311788856983, 0.012010413222014904, 0.010839397087693214, 0.011595101095736027]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.1 8 50
# Epoch 1/15
# 2/2 [==============================] - 5s 555ms/step - loss: 0.5719 - output_10_loss: 0.1694 - output_25_loss: 0.1434 - output_50_loss: 0.1192 - output_75_loss: 0.0748 - output_90_loss: 0.0617
# Epoch 2/15
# 2/2 [==============================] - 1s 572ms/step - loss: 0.3810 - output_10_loss: 0.0274 - output_25_loss: 0.0686 - output_50_loss: 0.1354 - output_75_loss: 0.1085 - output_90_loss: 0.0196
# Epoch 3/15
# 2/2 [==============================] - 1s 556ms/step - loss: 0.4161 - output_10_loss: 0.0265 - output_25_loss: 0.0655 - output_50_loss: 0.0986 - output_75_loss: 0.1563 - output_90_loss: 0.0413
# Epoch 4/15
# 2/2 [==============================] - 1s 573ms/step - loss: 0.2442 - output_10_loss: 0.0154 - output_25_loss: 0.0318 - output_50_loss: 0.0523 - output_75_loss: 0.0966 - output_90_loss: 0.0214
# Epoch 5/15
# 2/2 [==============================] - 1s 594ms/step - loss: 0.1305 - output_10_loss: 0.0091 - output_25_loss: 0.0184 - output_50_loss: 0.0221 - output_75_loss: 0.0353 - output_90_loss: 0.0148
# Epoch 6/15
# 2/2 [==============================] - 1s 559ms/step - loss: 0.1430 - output_10_loss: 0.0107 - output_25_loss: 0.0202 - output_50_loss: 0.0298 - output_75_loss: 0.0271 - output_90_loss: 0.0214
# Epoch 7/15
# 2/2 [==============================] - 1s 552ms/step - loss: 0.1312 - output_10_loss: 0.0067 - output_25_loss: 0.0129 - output_50_loss: 0.0229 - output_75_loss: 0.0341 - output_90_loss: 0.0201
# Epoch 8/15
# 2/2 [==============================] - 1s 587ms/step - loss: 0.1325 - output_10_loss: 0.0101 - output_25_loss: 0.0199 - output_50_loss: 0.0231 - output_75_loss: 0.0269 - output_90_loss: 0.0179
# Epoch 9/15
# 2/2 [==============================] - 2s 595ms/step - loss: 0.1259 - output_10_loss: 0.0102 - output_25_loss: 0.0194 - output_50_loss: 0.0233 - output_75_loss: 0.0245 - output_90_loss: 0.0170
# Epoch 10/15
# 2/2 [==============================] - 1s 561ms/step - loss: 0.1147 - output_10_loss: 0.0076 - output_25_loss: 0.0166 - output_50_loss: 0.0223 - output_75_loss: 0.0248 - output_90_loss: 0.0164
# Epoch 11/15
# 2/2 [==============================] - 1s 583ms/step - loss: 0.1089 - output_10_loss: 0.0069 - output_25_loss: 0.0134 - output_50_loss: 0.0260 - output_75_loss: 0.0229 - output_90_loss: 0.0162
# Epoch 12/15
# 2/2 [==============================] - 1s 596ms/step - loss: 0.1141 - output_10_loss: 0.0078 - output_25_loss: 0.0151 - output_50_loss: 0.0278 - output_75_loss: 0.0264 - output_90_loss: 0.0171
# Epoch 13/15
# 2/2 [==============================] - 1s 588ms/step - loss: 0.1055 - output_10_loss: 0.0059 - output_25_loss: 0.0177 - output_50_loss: 0.0228 - output_75_loss: 0.0253 - output_90_loss: 0.0169
# Epoch 14/15
# 2/2 [==============================] - 1s 575ms/step - loss: 0.0998 - output_10_loss: 0.0067 - output_25_loss: 0.0158 - output_50_loss: 0.0224 - output_75_loss: 0.0242 - output_90_loss: 0.0170
# Epoch 15/15
# 2/2 [==============================] - 1s 576ms/step - loss: 0.1070 - output_10_loss: 0.0086 - output_25_loss: 0.0147 - output_50_loss: 0.0236 - output_75_loss: 0.0282 - output_90_loss: 0.0204
# fit complete!
# train_time is: 25.960781574249268 seconds
# 100/100 [==============================] - 7s 68ms/step - loss: 0.0926 - output_10_loss: 0.0090 - output_25_loss: 0.0132 - output_50_loss: 0.0221 - output_75_loss: 0.0219 - output_90_loss: 0.0166
# train_loss is: [0.09262193739414215, 0.009015023708343506, 0.013155298307538033, 0.022138921543955803, 0.021854635328054428, 0.0165907833725214]
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0545 - output_10_loss: 0.0058 - output_25_loss: 0.0055 - output_50_loss: 0.0099 - output_75_loss: 0.0145 - output_90_loss: 0.0088
# test_loss is: [0.054451871663331985, 0.005848570726811886, 0.005467863287776709, 0.009942165575921535, 0.014496785588562489, 0.008829228579998016]
#
#
# learning_rate, n_unit, n_Dense_unit:  0.1 12 50
# Epoch 1/15
# 2/2 [==============================] - 6s 711ms/step - loss: 0.5288 - output_10_loss: 0.1396 - output_25_loss: 0.1332 - output_50_loss: 0.1004 - output_75_loss: 0.0863 - output_90_loss: 0.0665
# Epoch 2/15
# 2/2 [==============================] - 2s 729ms/step - loss: 0.4734 - output_10_loss: 0.0275 - output_25_loss: 0.0687 - output_50_loss: 0.1374 - output_75_loss: 0.1555 - output_90_loss: 0.0630
# Epoch 3/15
# 2/2 [==============================] - 2s 714ms/step - loss: 0.4773 - output_10_loss: 0.0275 - output_25_loss: 0.0687 - output_50_loss: 0.1374 - output_75_loss: 0.1410 - output_90_loss: 0.0724
# Epoch 4/15
# 2/2 [==============================] - 2s 756ms/step - loss: 0.3886 - output_10_loss: 0.0275 - output_25_loss: 0.0686 - output_50_loss: 0.1373 - output_75_loss: 0.0534 - output_90_loss: 0.0723
# Epoch 5/15
# 2/2 [==============================] - 2s 756ms/step - loss: 0.3777 - output_10_loss: 0.0273 - output_25_loss: 0.0680 - output_50_loss: 0.1369 - output_75_loss: 0.0459 - output_90_loss: 0.0719
# Epoch 6/15
# 2/2 [==============================] - 2s 719ms/step - loss: 0.3534 - output_10_loss: 0.0265 - output_25_loss: 0.0653 - output_50_loss: 0.1340 - output_75_loss: 0.0325 - output_90_loss: 0.0705
# Epoch 7/15
# 2/2 [==============================] - 2s 704ms/step - loss: 0.3005 - output_10_loss: 0.0223 - output_25_loss: 0.0507 - output_50_loss: 0.1119 - output_75_loss: 0.0312 - output_90_loss: 0.0635
# Epoch 8/15
# 2/2 [==============================] - 2s 764ms/step - loss: 0.1759 - output_10_loss: 0.0175 - output_25_loss: 0.0273 - output_50_loss: 0.0425 - output_75_loss: 0.0276 - output_90_loss: 0.0424
# Epoch 9/15
# 2/2 [==============================] - 2s 735ms/step - loss: 0.1280 - output_10_loss: 0.0071 - output_25_loss: 0.0177 - output_50_loss: 0.0283 - output_75_loss: 0.0232 - output_90_loss: 0.0307
# Epoch 10/15
# 2/2 [==============================] - 2s 731ms/step - loss: 0.1590 - output_10_loss: 0.0141 - output_25_loss: 0.0288 - output_50_loss: 0.0273 - output_75_loss: 0.0416 - output_90_loss: 0.0211
# Epoch 11/15
# 2/2 [==============================] - 2s 716ms/step - loss: 0.1443 - output_10_loss: 0.0140 - output_25_loss: 0.0290 - output_50_loss: 0.0254 - output_75_loss: 0.0328 - output_90_loss: 0.0155
# Epoch 12/15
# 2/2 [==============================] - 2s 723ms/step - loss: 0.1247 - output_10_loss: 0.0111 - output_25_loss: 0.0214 - output_50_loss: 0.0228 - output_75_loss: 0.0246 - output_90_loss: 0.0179
# Epoch 13/15
# 2/2 [==============================] - 2s 725ms/step - loss: 0.1286 - output_10_loss: 0.0090 - output_25_loss: 0.0190 - output_50_loss: 0.0248 - output_75_loss: 0.0257 - output_90_loss: 0.0247
# Epoch 14/15
# 2/2 [==============================] - 2s 708ms/step - loss: 0.1107 - output_10_loss: 0.0063 - output_25_loss: 0.0141 - output_50_loss: 0.0223 - output_75_loss: 0.0263 - output_90_loss: 0.0184
# Epoch 15/15
# 2/2 [==============================] - 2s 708ms/step - loss: 0.1264 - output_10_loss: 0.0076 - output_25_loss: 0.0218 - output_50_loss: 0.0358 - output_75_loss: 0.0230 - output_90_loss: 0.0162
# fit complete!
# train_time is: 34.17510795593262 seconds
# 100/100 [==============================] - 8s 73ms/step - loss: 0.1052 - output_10_loss: 0.0086 - output_25_loss: 0.0162 - output_50_loss: 0.0205 - output_75_loss: 0.0241 - output_90_loss: 0.0163
# train_loss is: [0.10523055493831635, 0.008603742346167564, 0.0161812212318182, 0.020464176312088966, 0.024059923365712166, 0.016293389722704887]
# 55/55 [==============================] - 4s 76ms/step - loss: 0.0748 - output_10_loss: 0.0117 - output_25_loss: 0.0083 - output_50_loss: 0.0150 - output_75_loss: 0.0107 - output_90_loss: 0.0096
# test_loss is: [0.07482511550188065, 0.011673513799905777, 0.008278457447886467, 0.015016020275652409, 0.010652333498001099, 0.009576726704835892]
#
#
# id:  100061976235503665
# learning_rate, n_unit, n_Dense_unit:  0.001 4 10
# Epoch 1/15
# 2/2 [==============================] - 5s 492ms/step - loss: 0.6572 - output_10_loss: 0.2178 - output_25_loss: 0.1902 - output_50_loss: 0.1514 - output_75_loss: 0.0684 - output_90_loss: 0.0295
# Epoch 2/15
# 2/2 [==============================] - 1s 452ms/step - loss: 0.6530 - output_10_loss: 0.2153 - output_25_loss: 0.1887 - output_50_loss: 0.1514 - output_75_loss: 0.0682 - output_90_loss: 0.0294
# Epoch 3/15
# 2/2 [==============================] - 1s 460ms/step - loss: 0.6489 - output_10_loss: 0.2128 - output_25_loss: 0.1874 - output_50_loss: 0.1515 - output_75_loss: 0.0681 - output_90_loss: 0.0292
# Epoch 4/15
# 2/2 [==============================] - 1s 447ms/step - loss: 0.6449 - output_10_loss: 0.2104 - output_25_loss: 0.1860 - output_50_loss: 0.1515 - output_75_loss: 0.0680 - output_90_loss: 0.0290
# Epoch 5/15
# 2/2 [==============================] - 1s 428ms/step - loss: 0.6409 - output_10_loss: 0.2080 - output_25_loss: 0.1847 - output_50_loss: 0.1515 - output_75_loss: 0.0678 - output_90_loss: 0.0289
# Epoch 6/15
# 2/2 [==============================] - 1s 454ms/step - loss: 0.6369 - output_10_loss: 0.2055 - output_25_loss: 0.1834 - output_50_loss: 0.1515 - output_75_loss: 0.0677 - output_90_loss: 0.0287
# Epoch 7/15
# 2/2 [==============================] - 1s 436ms/step - loss: 0.6329 - output_10_loss: 0.2030 - output_25_loss: 0.1822 - output_50_loss: 0.1515 - output_75_loss: 0.0676 - output_90_loss: 0.0286
# Epoch 8/15
# 2/2 [==============================] - 1s 476ms/step - loss: 0.6289 - output_10_loss: 0.2005 - output_25_loss: 0.1809 - output_50_loss: 0.1514 - output_75_loss: 0.0675 - output_90_loss: 0.0285
# Epoch 9/15
# 2/2 [==============================] - 1s 465ms/step - loss: 0.6248 - output_10_loss: 0.1979 - output_25_loss: 0.1796 - output_50_loss: 0.1514 - output_75_loss: 0.0674 - output_90_loss: 0.0284
# Epoch 10/15
# 2/2 [==============================] - 1s 454ms/step - loss: 0.6205 - output_10_loss: 0.1952 - output_25_loss: 0.1784 - output_50_loss: 0.1513 - output_75_loss: 0.0673 - output_90_loss: 0.0283
# Epoch 11/15
# 2/2 [==============================] - 1s 441ms/step - loss: 0.6161 - output_10_loss: 0.1925 - output_25_loss: 0.1771 - output_50_loss: 0.1512 - output_75_loss: 0.0671 - output_90_loss: 0.0282
# Epoch 12/15
# 2/2 [==============================] - 1s 433ms/step - loss: 0.6114 - output_10_loss: 0.1896 - output_25_loss: 0.1758 - output_50_loss: 0.1510 - output_75_loss: 0.0670 - output_90_loss: 0.0281
# Epoch 13/15
# 2/2 [==============================] - 1s 441ms/step - loss: 0.6066 - output_10_loss: 0.1865 - output_25_loss: 0.1744 - output_50_loss: 0.1508 - output_75_loss: 0.0668 - output_90_loss: 0.0280
# Epoch 14/15
# 2/2 [==============================] - 1s 440ms/step - loss: 0.6015 - output_10_loss: 0.1833 - output_25_loss: 0.1730 - output_50_loss: 0.1505 - output_75_loss: 0.0667 - output_90_loss: 0.0279
# Epoch 15/15
# 2/2 [==============================] - 1s 471ms/step - loss: 0.5961 - output_10_loss: 0.1800 - output_25_loss: 0.1715 - output_50_loss: 0.1502 - output_75_loss: 0.0665 - output_90_loss: 0.0278
# fit complete!
# train_time is: 21.10238480567932 seconds
#  44/100 [============>.................] - ETA: 4s - loss: 0.5198 - output_10_loss: 0.1521 - output_25_loss: 0.1475 - output_50_loss: 0.1353 - output_75_loss: 0.0595 - output_90_loss: 0.0253

# %%
# read in validation results and identify hyper parameter combination with lowest loss
path =  ('') #set input path

data=[]
for i, file in enumerate(os.listdir(path)):
    if file.startswith('loss'):
        output_file = pd.read_pickle(os.path.join(path,file))
        index=pd.Series(range(0,len(output_file)))
        output_file=output_file.set_index(index)
        min_idx=output_file['test_loss'].idxmin()
        data.append(output_file.iloc[min_idx,])

df_min_test_loss = pd.DataFrame(data)
df_min_test_loss.to_pickle('') #set output path

# %%
##Load the model with the best hyper parameter combination and run it on test set

## Data set split
#number of total observations
n_total = len(input_data.index.unique()) 
# number of observations used for training
n_train = int(round(n_total * 0.8, 0)) # set accordingly
# number of observations used for testing
n_test = int(n_train + round(n_total * 0.2, 0)) # set accordingly

path = '' # set output path

method = 'GRU' # GRU, LSTM, Regression
weather_included = 1 # 1: withWeather, 0: withoutWeather

for i in id_list:
    print('id: ', i)
    df_min_test_loss = pd.read_pickle('') # set input path to min Test Loss Parameters
    df_min_test_loss = df_min_test_loss[df_min_test_loss['id'] == i]
    learning_rate = float(df_min_test_loss['learning_rate'])
    n_Dense_unit = int(df_min_test_loss['n_Dense_unit'])
    n_unit = int(df_min_test_loss['n_unit'])
    hyper_params = [(method, weather_included, learning_rate, n_Dense_unit, n_unit)]
    print('Optimal hyperparams: ', hyper_params)
    locals()['yhat_net_'+str(i)], locals()['yloss_net_'+str(i)] =  forecast(input_data, i , n_steps_out, n_total, n_train, n_steps_in, n_test, hyper_params, path)

# %%
# read in test results and aggregate them into one file
path = ('') # set input path to test output

data=pd.DataFrame()
for i, file in enumerate(os.listdir(path)):
    if file.startswith('loss'):
        output_file = pd.read_pickle(os.path.join(path,file))
        data = data.append(output_file)

data.to_pickle('') # set output path

# %%
#recombine aggregated test results with customer information for houshold-type specific evaluation

data = pd.read_pickle('')  #set input path to aggragated data
df_customergroups = pd.read_pickle('')  #set input path to initial preprocessed_input_data
df_customergroups = df_customergroups.drop(['weekday', 'time of day',	'wind_speed(Km/h)',	'temp(C)','rel_humi',	'pressfc', 'delivery_service_class'], axis=1)
df_customergroups.net_consumption.describe()
df_customergroups.groupby(['id']).net_consumption.std()
df_customergroups
df_customergroups.reset_index(inplace=True)  
df_customergroups = df_customergroups.set_index(['id'])
df_customergroups
data = data.set_index(['id'])
data = data.join(df_customergroups, how = 'left')
data.to_pickle('') # set output path

# %% [markdown]
# # Plotting

# %%
#Plot performance comparison of forecasting methods across customer types
ylosses = pd.read_pickle('') #set input path to combined aggregated results with houshold-types
ylosses = ylosses.groupby(['id', 'household_type', 'method', 'weather_included']).mean('test_loss')

ylosses.reset_index(inplace=True)  
ylosses = ylosses.sort_values(by = 'id')
ylosses = ylosses.set_index(['id'])

#extract losses of each method
ylosses_GRU1 = ylosses.loc[(ylosses['weather_included'] == 1) & (ylosses['method'] == 'GRU')]
ylosses_LSTM1 = ylosses.loc[(ylosses['weather_included'] == 1) & (ylosses['method'] == 'LSTM')]
ylosses_Regression1 = ylosses.loc[(ylosses['weather_included'] == 1) & (ylosses['method'] == 'Regression')]
ylosses_LSTM0 = ylosses.loc[(ylosses['weather_included'] == 0) & (ylosses['method'] == 'LSTM')]

fig, ax = plt.subplots(figsize = (8, 6))
ax.scatter(x = ylosses_LSTM1['test_loss'].values, y = ylosses_GRU1['test_loss'].values, color = '#006d2c', s = 22, alpha = 0.8, marker = 'D', label = 'QLSTM')
ax.scatter(x = ylosses_Regression1['test_loss'].values, y = ylosses_GRU1['test_loss'].values, color = '#cb181d', s = 22, alpha = 0.8, marker = 's', label = 'QREGNN')
ax.scatter(x = ylosses_LSTM0['test_loss'].values, y = ylosses_GRU1['test_loss'].values, color = '#08519c', s = 22, alpha = 0.8, marker = 'v', label = 'QLSTM_noWeather')
ax.plot([0, 0.55], [0, 0.55], c = 'black', label = 'y=x', linewidth = 2)
ax.legend(fontsize = 15)
ax.set_ylim([0, 0.55])
ax.set_xlim([0, 0.55])
ax.set_xlabel('Pinball Loss of benchmark methods $[kWh]$', fontsize = 15)
ax.set_ylabel('Pinball Loss of QGRU $[kWh]$', fontsize = 15)
fig.savefig('') # set output path

# %%
# plot annual net consumption
data = pd.read_pickle('') #set input path to aggragated data
df_customergroups = pd.read_pickle('')  #set input path to initial preprocessed_input_data
df_std = df_customergroups.groupby(['id']).net_consumption.std()
df_std = df_std.set_index('id')


ylosses = pd.read_pickle('') #set input path to combined aggregated results with houshold-types
ylosses = ylosses.groupby(['id', 'household_type', 'method', 'weather_included']).mean(['test_loss'])
ylosses.reset_index(inplace=True)  
ylosses = ylosses.sort_values(by = 'id')
ylosses = ylosses.set_index(['id'])

ylosses = ylosses.join(df_std, how = 'left')

ylosses_GRU1 = ylosses.loc[(ylosses['weather_included'] == 0) & (ylosses['method'] == 'LSTM')]
ylosses_GRU1_nono = ylosses_GRU1.loc[(ylosses_GRU1['household_type'] == 'solar_no_heating_no')]
ylosses_GRU1_noyes = ylosses_GRU1.loc[(ylosses_GRU1['household_type'] == 'solar_no_heating_yes')]
ylosses_GRU1_yesno = ylosses_GRU1.loc[(ylosses_GRU1['household_type'] == 'solar_yes_heating_no')]
ylosses_GRU1_yesyes = ylosses_GRU1.loc[(ylosses_GRU1['household_type'] == 'solar_yes_heating_yes')]


fig, ax = plt.subplots(figsize = (8, 6))
ax.scatter(x = ylosses_GRU1_nono['net_consumption'].values, y = ylosses_GRU1_nono['test_loss'].values, color = '#9ecae1', s = 30, alpha = 1, marker = 's', label = 'Household')
ax.scatter(x = ylosses_GRU1_noyes['net_consumption'].values, y = ylosses_GRU1_noyes['test_loss'].values, color = '#4292c6', s = 30, alpha = 1, marker = 'D', label = 'Household with heating')
ax.scatter(x = ylosses_GRU1_yesno['net_consumption'].values, y = ylosses_GRU1_yesno['test_loss'].values, color = '#08519c', s = 30, alpha = 1, marker = 'v', label = 'Household with solar')
ax.scatter(x = ylosses_GRU1_yesyes['net_consumption'].values, y = ylosses_GRU1_yesyes['test_loss'].values, color = '#08306b', s = 30, alpha = 1, marker = 'o', label = 'Household with heating and solar')
ax.legend(fontsize = 15, loc = 'upper left')
ax.set_ylim([0, 0.7])
ax.set_xlabel('Annual net consumption $[kWh]$', fontsize = 15)
ax.set_ylabel('Average hourly Pinball Loss $[kWh]$', fontsize = 15)
fig.savefig('') # set output path
